# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import time 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support 
# %matplotlib inline
from IPython.display import display
from six import StringIO
from matplotlib import pyplot as plt
from matplotlib.lines import Line2D

from scipy.stats import pearsonr

from sklearn.cluster import KMeans 
from sklearn import metrics
from sklearn.metrics import pairwise_distances

from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering

# %%
import numpy as np
import pandas as pd 
from sklearn.preprocessing import LabelEncoder

DIAMETER_METHODS = ['mean_cluster', 'farthest']
CLUSTER_DISTANCE_METHODS = ['nearest', 'farthest']


def inter_cluster_distances(labels, distances, method='nearest'):
  
    if method not in CLUSTER_DISTANCE_METHODS:
        raise ValueError(
            'method must be one of {}'.format(CLUSTER_DISTANCE_METHODS))

    if method == 'nearest':
        return __cluster_distances_by_points(labels, distances)
    elif method == 'farthest':
        return __cluster_distances_by_points(labels, distances, farthest=True)


def __cluster_distances_by_points(labels, distances, farthest=False):
    n_unique_labels = len(np.unique(labels))
    cluster_distances = np.full((n_unique_labels, n_unique_labels),
                                float('inf') if not farthest else 0)

    np.fill_diagonal(cluster_distances, 0)

    for i in np.arange(0, len(labels) - 1):
        for ii in np.arange(i, len(labels)):
            if labels[i] != labels[ii] and (
                (not farthest and
                 distances[i, ii] < cluster_distances[labels[i], labels[ii]])
                    or
                (farthest and
                 distances[i, ii] > cluster_distances[labels[i], labels[ii]])):
                cluster_distances[labels[i], labels[ii]] = cluster_distances[
                    labels[ii], labels[i]] = distances[i, ii]
    return cluster_distances


def diameter(labels, distances, method='farthest'):
   
    if method not in DIAMETER_METHODS:
        raise ValueError('method must be one of {}'.format(DIAMETER_METHODS))

    n_clusters = len(np.unique(labels))
    diameters = np.zeros(n_clusters)

    if method == 'mean_cluster':
        for i in range(0, len(labels) - 1):
            for ii in range(i + 1, len(labels)):
                if labels[i] == labels[ii]:
                    diameters[labels[i]] += distances[i, ii]

        for i in range(len(diameters)):
            diameters[i] /= sum(labels == i)

    elif method == 'farthest':
        for i in range(0, len(labels) - 1):
            for ii in range(i + 1, len(labels)):
                if labels[i] == labels[ii] and distances[i, ii] > diameters[
                        labels[i]]:
                    diameters[labels[i]] = distances[i, ii]
    return diameters


def dunn(labels, distances, diameter_method='farthest',
         cdist_method='nearest'):
    

    labels = LabelEncoder().fit(labels).transform(labels)

    ic_distances = inter_cluster_distances(labels, distances, cdist_method)
    min_distance = min(ic_distances[ic_distances.nonzero()])
    max_diameter = max(diameter(labels, distances, diameter_method))

    return min_distance / max_diameter

# %%
from IPython.display import display, HTML
from sklearn.tree import _tree, DecisionTreeClassifier
import pandas as pd

def pretty_print(df):
    return display( HTML( df.to_html().replace("\\n","<br>") ) )

def get_class_rules(tree: DecisionTreeClassifier, feature_names: list):
    inner_tree: _tree.Tree = tree.tree_
    classes = tree.classes_
    class_rules_dict = dict()
    
    
    def tree_dfs(node_id=0, current_rule=[]):
        split_feature = inner_tree.feature[node_id]
        if split_feature != _tree.TREE_UNDEFINED: # internal node
            name = feature_names[split_feature]
            threshold = inner_tree.threshold[node_id]
      # left child
            left_rule = current_rule + ["({} <= {})".format(name, threshold)]
            tree_dfs(inner_tree.children_left[node_id], left_rule)
      # right child
            right_rule = current_rule + ["({} > {})".format(name, threshold)]
            tree_dfs(inner_tree.children_right[node_id], right_rule)
        else: # leaf
            dist = inner_tree.value[node_id][0]
            dist = dist/dist.sum()
            max_idx = dist.argmax()
            if len(current_rule) == 0:
                rule_string = "ALL"
            else:
                rule_string = " and ".join(current_rule)
      # register new rule to dictionary
            selected_class = classes[max_idx]
            class_probability = dist[max_idx]
            class_rules = class_rules_dict.get(selected_class, [])
            class_rules.append((rule_string, class_probability))
            class_rules_dict[selected_class] = class_rules
    
    tree_dfs() # start from root, node_id = 0
    return class_rules_dict

def cluster_report(data: pd.DataFrame, clusters, min_samples_leaf=50, pruning_level=0.01):
    tree = DecisionTreeClassifier(min_samples_leaf=min_samples_leaf, ccp_alpha=pruning_level)
    tree.fit(data, clusters)
    
    # Generate Report
    feature_names = data.columns
    class_rule_dict = get_class_rules(tree, feature_names)

    report_class_list = []
    for class_name in class_rule_dict.keys():
        rule_list = class_rule_dict[class_name]
        combined_string = ""
        for rule in rule_list:
            combined_string += "[{}] {}\n\n".format(rule[1], rule[0])
        report_class_list.append((class_name, combined_string))
        
    cluster_instance_df = pd.Series(clusters).value_counts().reset_index()
    cluster_instance_df.columns = ['class_name', 'instance_count']
    report_df = pd.DataFrame(report_class_list, columns=['class_name', 'rule_list'])
    report_df = pd.merge(cluster_instance_df, report_df, on='class_name', how='left')
    print(feature_names)
    pretty_print(report_df.sort_values(by='class_name')[['class_name', 'instance_count', 'rule_list']])

# %%
dataf=pd.read_csv('FULL DATA.csv')

dataf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   AGEGROUP     300 non-null    int64
#  1   ageinmonths  300 non-null    int64
#  2   PV           300 non-null    int64
#  3   SR           300 non-null    int64
#  4   GU           300 non-null    int64
#  5   REFMNG       300 non-null    int64
#  6   RELMNG       300 non-null    int64
#  7   EL           300 non-null    int64
#  8   TOTAL        300 non-null    int64
# dtypes: int64(9)
# memory usage: 21.2 KB

# %% [markdown]
# # Peason correlation

# %%
dataf.corr(method = 'pearson', min_periods = 1)
# Out:
#              AGEGROUP  ageinmonths        PV        SR        GU    REFMNG  \
# AGEGROUP     1.000000     0.989484  0.760785  0.744749  0.550699  0.791940
# ageinmonths  0.989484     1.000000  0.770036  0.753923  0.542752  0.799050
# PV           0.760785     0.770036  1.000000  0.647086  0.556428  0.647359
# SR           0.744749     0.753923  0.647086  1.000000  0.394013  0.619371
# GU           0.550699     0.542752  0.556428  0.394013  1.000000  0.356654
# REFMNG       0.791940     0.799050  0.647359  0.619371  0.356654  1.000000
# RELMNG       0.818825     0.823412  0.594285  0.645616  0.428535  0.693055
# EL           0.815002     0.809715  0.668376  0.650380  0.538894  0.606768
# TOTAL        0.938661     0.942078  0.819717  0.805296  0.613950  0.812597
#
#                RELMNG        EL     TOTAL
# AGEGROUP     0.818825  0.815002  0.938661
# ageinmonths  0.823412  0.809715  0.942078
# PV           0.594285  0.668376  0.819717
# SR           0.645616  0.650380  0.805296
# GU           0.428535  0.538894  0.613950
# REFMNG       0.693055  0.606768  0.812597
# RELMNG       1.000000  0.680759  0.872470
# EL           0.680759  1.000000  0.871268
# TOTAL        0.872470  0.871268  1.000000

# %%
lc=list(dataf.columns)
lc2=lc.copy()
pcclist=[]

minscore=2
maxscore=0

for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        list1 = dataf[lc[lc.index(n1)]]
        list2 = dataf[lc2[lc2.index(n2)]]
        corr, _ = pearsonr(list1, list2)
        name2=str(n1 +' and '+n2)
        pccitem=[name2,corr]
        pcclist.append(pccitem)
        #print(name2)
        #print(n1 +' and '+ n2 + ' is : %.3f' % corr)
        #plt.scatter(dataf[lc[lc.index(n1)]], dataf[lc2[lc2.index(n2)]])
        if corr< minscore:
            minscore=corr
            minatr1=n1
            minatr2=n2
        if corr> maxscore:
            maxscore=corr
            maxatr1=n1
            maxatr2=n2

print(minatr1 +' and '+ minatr2 + ' is : %.3f' % minscore)
print(maxatr1 +' and '+ maxatr2 + ' is : %.3f' % maxscore)
# Out:
# GU and REFMNG is : 0.357
# AGEGROUP and ageinmonths is : 0.989

# %%
pccdf = pd.DataFrame(pcclist, columns =['Attributes', 'Correlation'])

pccdf.sort_values(by='Correlation').head(10)
# Out:
#             Attributes  Correlation
# 26       GU and REFMNG     0.356654
# 21           SR and GU     0.394013
# 27       GU and RELMNG     0.428535
# 28           GU and EL     0.538894
# 10  ageinmonths and GU     0.542752
# 3      AGEGROUP and GU     0.550699
# 16           PV and GU     0.556428
# 18       PV and RELMNG     0.594285
# 31       REFMNG and EL     0.606768
# 29        GU and TOTAL     0.613950

# %%
print(dataf.var())
# Out:
# AGEGROUP          2.926421
# ageinmonths     107.581839
# PV               30.583099
# SR               26.069967
# GU               14.255017
# REFMNG           35.382598
# RELMNG          104.943266
# EL               81.527313
# TOTAL          1074.694437
# dtype: float64

# %%
from sklearn.feature_selection import VarianceThreshold

vhold=VarianceThreshold(threshold=50)
vhold.fit(dataf)
vhold.get_support()
# Out:
# array([False,  True, False, False, False, False,  True,  True,  True])

# %% [markdown]
# # Drop features

# %%
df=dataf.drop(['AGEGROUP', 'ageinmonths','TOTAL','PV','EL'], axis = 1)
df.head()
# Out:
#    SR  GU  REFMNG  RELMNG
# 0   0   3       8       4
# 1   0   6       1       4
# 2   5   7       0       2
# 3   2  11       0       0
# 4   0  10       2       0

# %%
a1=1
a2=3
xatt=df.iloc[:,lambda df: [a1,a2]]
print(xatt)
# Out:
#      GU  RELMNG
# 0     3       4
# 1     6       4
# 2     7       2
# 3    11       0
# 4    10       0
# ..   ..     ...
# 295  17      20
# 296  16      33
# 297  17      33
# 298  15      32
# 299  16      33
#
# [300 rows x 2 columns]

# %% [markdown]
# # Kmeans k=300

# %%
wcss=[]
prev=0




for i in range(2,12):
    kmeans = KMeans(i)
    kmeans.fit(df)
    wcss_iter = kmeans.inertia_
    if prev==0:
        prev=wcss_iter
    else:
        print(i-1,i,prev-wcss_iter)
        prev=wcss_iter
    wcss.append(wcss_iter)

number_clusters = range(2,12)
plt.plot(number_clusters,wcss)
plt.title('The Elbow title')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# 2 3 6615.909570557018
# 3 4 2491.227731082299
# 4 5 1566.6246185417585
# 5 6 1351.273206654454
# 6 7 853.5707958707972
# 7 8 726.5688263319716
# 8 9 587.6983234300305
# 9 10 413.95911995412007
# 10 11 281.87153159765876
# Text(0, 0.5, 'WCSS')

# %%
numk=5

# %% [markdown]
# # kmeas 300

# %%
kmean = KMeans(n_clusters = numk, init = "k-means++")
kmean.fit(xatt)

from sklearn.metrics.pairwise import euclidean_distances

labelkm = kmean.fit_predict(xatt)
scoresm = metrics.silhouette_score(xatt, kmean.labels_, metric='euclidean')

d = euclidean_distances(xatt)
diameter_method='farthest'
cdist_method='nearest'
dunkm = dunn(labelkm, d, diameter_method, cdist_method)

print(scoresm,dunkm)


fig, ax = plt.subplots() 
plt.scatter(df.iloc[:,a1], df.iloc[:,a2], c=kmean.labels_) 
plt.scatter(kmean.cluster_centers_[:,0], kmean.cluster_centers_[:,1],marker='x', color='red')
# Out:
# 0.37192449901856683 0.05322462954123495

# %%
ym= labelkm

# %%
ymean2= labelkm

cluster_report(xatt, ymean2, min_samples_leaf=50, pruning_level=0.01)
# Out:
# Index(['GU', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>64</td>
#       <td>[0.65625] (RELMNG &gt; 8.5) and (RELMNG &gt; 17.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>90</td>
#       <td>[1.0] (RELMNG &lt;= 8.5) and (GU &gt; 9.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>65</td>
#       <td>[0.8421052631578947] (RELMNG &lt;= 8.5) and (GU &lt;= 9.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>29</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>52</td>
#       <td>[0.96] (RELMNG &gt; 8.5) and (RELMNG &lt;= 17.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>

# %%
lc=list(df.columns)
lc2=lc.copy()
#silhlist=[]

for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        aa1=lc.index(n1)
        aa2=lc.index(n2)
        xatt2=df.iloc[:,lambda df: [aa1, aa2]]
        
        kmeans1 = KMeans(numk)
        kmeans1.fit(xatt2)
        identified_clusters = kmeans1.fit_predict(xatt2)
        
        scoresm = metrics.silhouette_score(xatt2, kmeans1.labels_, metric='euclidean')
        #silhitem=[lc[lc.index(n1)],lc2[lc2.index(n2)],scoresm]
        #silhlist.append(silhitem)
        
        cluster_report(xatt2, identified_clusters, min_samples_leaf=50, pruning_level=0.01)
        
        fig, ax = plt.subplots()
        scatter=plt.scatter(df.iloc[:,aa1], df.iloc[:,aa2], c=kmeans1.labels_) 
        plt.scatter(kmeans1.cluster_centers_[:,0], kmeans1.cluster_centers_[:,1],marker='x', color='red')
        plt.title('K-means Clustering data=300: '+lc[lc.index(n1)] + ' vs '+ lc2[lc2.index(n2)])
        #+ ' Silhouetter Score: %.3f' % scoresm
        plt.xlabel(lc[lc.index(n1)])
        plt.ylabel(lc2[lc2.index(n2)])
        plt.colorbar(scatter)
        plt.show()
# Out:
# Index(['SR', 'GU'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>85</td>
#       <td>[0.7333333333333333] (SR &lt;= 7.5) and (SR &gt; 1.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>81</td>
#       <td>[0.8636363636363636] (SR &gt; 7.5) and (SR &lt;= 11.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>24</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>83</td>
#       <td>[0.8701298701298701] (SR &lt;= 7.5) and (SR &lt;= 1.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>27</td>
#       <td>[0.5192307692307693] (SR &gt; 7.5) and (SR &gt; 11.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'REFMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>58</td>
#       <td>[0.8923076923076924] (REFMNG &gt; 6.5) and (SR &gt; 4.5) and (SR &gt; 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>79</td>
#       <td>[0.9753086419753086] (REFMNG &lt;= 6.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>54</td>
#       <td>[0.5444444444444444] (REFMNG &gt; 6.5) and (SR &gt; 4.5) and (SR &lt;= 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>50</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>59</td>
#       <td>[0.921875] (REFMNG &gt; 6.5) and (SR &lt;= 4.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>29</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>104</td>
#       <td>[0.9902912621359223] (RELMNG &lt;= 8.5) and (SR &lt;= 4.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>49</td>
#       <td>[0.7931034482758621] (RELMNG &gt; 8.5) and (RELMNG &lt;= 18.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>63</td>
#       <td>[0.6363636363636364] (RELMNG &gt; 8.5) and (RELMNG &gt; 18.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>55</td>
#       <td>[0.9607843137254902] (RELMNG &lt;= 8.5) and (SR &gt; 4.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'REFMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>80</td>
#       <td>[0.7596153846153846] (REFMNG &gt; 5.5) and (REFMNG &lt;= 13.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>54</td>
#       <td>[0.8548387096774194] (REFMNG &gt; 5.5) and (REFMNG &gt; 13.5) and (GU &lt;= 12.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>67</td>
#       <td>[1.0] (REFMNG &gt; 5.5) and (REFMNG &gt; 13.5) and (GU &gt; 12.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>75</td>
#       <td>[0.9733333333333334] (REFMNG &lt;= 5.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>24</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>68</td>
#       <td>[0.8933333333333333] (RELMNG &lt;= 7.5) and (GU &lt;= 9.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>67</td>
#       <td>[0.6875] (RELMNG &gt; 7.5) and (RELMNG &gt; 17.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>55</td>
#       <td>[0.9642857142857143] (RELMNG &gt; 7.5) and (RELMNG &lt;= 17.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>29</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>4</td>
#       <td>81</td>
#       <td>[1.0] (RELMNG &lt;= 7.5) and (GU &gt; 9.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['REFMNG', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>65</td>
#       <td>[0.6590909090909091] (REFMNG &gt; 6.5) and (RELMNG &gt; 9.5) and (RELMNG &gt; 18.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>76</td>
#       <td>[0.95] (REFMNG &gt; 6.5) and (RELMNG &lt;= 9.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>47</td>
#       <td>[0.8627450980392157] (REFMNG &gt; 6.5) and (RELMNG &gt; 9.5) and (RELMNG &lt;= 18.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>82</td>
#       <td>[1.0] (REFMNG &lt;= 6.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>30</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # sampling

# %%
from sklearn.utils import resample

doublelen=int(3*len(df))

dfsm = resample(df , n_samples=doublelen)
dfsm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 900 entries, 202 to 121
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SR      900 non-null    int64
#  1   GU      900 non-null    int64
#  2   REFMNG  900 non-null    int64
#  3   RELMNG  900 non-null    int64
# dtypes: int64(4)
# memory usage: 35.2 KB

# %%
dfsm.corr(method = 'pearson', min_periods = 1)
# Out:
#               SR        GU    REFMNG    RELMNG
# SR      1.000000  0.412172  0.638336  0.646785
# GU      0.412172  1.000000  0.374169  0.422882
# REFMNG  0.638336  0.374169  1.000000  0.685782
# RELMNG  0.646785  0.422882  0.685782  1.000000

# %%
lc=list(dfsm.columns)
lc2=lc.copy()
pccsmlist=[]

minscore=2
maxscore=0

for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        list1 = dfsm[lc[lc.index(n1)]]
        list2 = dfsm[lc2[lc2.index(n2)]]
        corr, _ = pearsonr(list1, list2)
        name2=str(n1 +' and '+n2)
        pccsmitem=[name2,corr]
        pccsmlist.append(pccsmitem)
        #print(name2)
        #print(n1 +' and '+ n2 + ' is : %.3f' % corr)
        #plt.scatter(dataf[lc[lc.index(n1)]], dataf[lc2[lc2.index(n2)]])
        if corr< minscore:
            minscore=corr
            minatr1=n1
            minatr2=n2
        if corr> maxscore:
            maxscore=corr
            maxatr1=n1
            maxatr2=n2
            
pccsmdf = pd.DataFrame(pccsmlist, columns =['Attributes', 'Correlation'])
print(dfsm.var())
pccsmdf.sort_values(by='Correlation').head()
# Out:
# SR         24.952090
# GU         12.638260
# REFMNG     36.124923
# RELMNG    101.005427
# dtype: float64
#       Attributes  Correlation
# 3  GU and REFMNG     0.374169
# 0      SR and GU     0.412172
# 4  GU and RELMNG     0.422882
# 1  SR and REFMNG     0.638336
# 2  SR and RELMNG     0.646785

# %% [markdown]
# # k-means sampling

# %%
wcss=[]
prev=0
a1=2
a2=3
xattsm1=dfsm.iloc[:,lambda df: [a1,a2]]

for i in range(2,12):
    kmeans = KMeans(i)
    kmeans.fit(xattsm1)
    wcss_iter = kmeans.inertia_
    if prev==0:
        prev=wcss_iter
    else:
        print(i-1,i,prev-wcss_iter)
        prev=wcss_iter
    wcss.append(wcss_iter)

number_clusters = range(2,12)
plt.plot(number_clusters,wcss)
plt.title('The Elbow title')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# 2 3 16361.147191606255
# 3 4 7058.649204782541
# 4 5 3010.0619491009274
# 5 6 2121.2016532239577
# 6 7 1169.1167659114599
# 7 8 941.5581736857393
# 8 9 762.8063700207085
# 9 10 794.9436813030743
# 10 11 491.0573670155236
# Text(0, 0.5, 'WCSS')

# %%
lcsm=list(dfsm.columns)
lc2sm=lcsm.copy()

silhsmlist=[]

for n1 in lcsm:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2sm.remove(n1)
    for n2 in lc2sm:
        aa1=lcsm.index(n1)
        aa2=lcsm.index(n2)
        xattsm=dfsm.iloc[:,lambda datafsm: [aa1, aa2]]
        kmeanssm = KMeans(numk)
        kmeanssm.fit(xattsm)
        identified_clusters = kmeanssm.fit_predict(xattsm)
        
        cluster_report(xattsm, identified_clusters, min_samples_leaf=50, pruning_level=0.01)
        
        fig, ax = plt.subplots()
        scatter=plt.scatter(dfsm.iloc[:,aa1], dfsm.iloc[:,aa2], c=kmeanssm.labels_) 
        plt.scatter(kmeanssm.cluster_centers_[:,0], kmeanssm.cluster_centers_[:,1],marker='x', color='red')
        plt.title('K-means Clustering data=900: '+lcsm[lcsm.index(n1)] + ' vs '+ lc2sm[lc2sm.index(n2)])
        plt.xlabel(lcsm[lcsm.index(n1)])
        plt.ylabel(lc2sm[lc2sm.index(n2)])
        plt.colorbar(scatter)
        plt.show()
# Out:
# Index(['SR', 'GU'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>190</td>
#       <td>[0.9368421052631579] (SR &gt; 6.5) and (GU &gt; 12.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>259</td>
#       <td>[0.9679144385026738] (SR &lt;= 6.5) and (SR &lt;= 1.5) and (GU &lt;= 10.5)<br><br>[0.5737704918032787] (SR &lt;= 6.5) and (SR &lt;= 1.5) and (GU &gt; 10.5)<br><br>[0.4358974358974359] (SR &lt;= 6.5) and (SR &gt; 1.5) and (GU &lt;= 9.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>257</td>
#       <td>[0.9575471698113207] (SR &lt;= 6.5) and (SR &gt; 1.5) and (GU &gt; 9.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>47</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>147</td>
#       <td>[0.8546511627906976] (SR &gt; 6.5) and (GU &lt;= 12.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'REFMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>214</td>
#       <td>[1.0] (REFMNG &lt;= 6.5) and (SR &lt;= 2.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>217</td>
#       <td>[0.6607142857142857] (REFMNG &gt; 6.5) and (SR &gt; 4.5) and (REFMNG &lt;= 15.5) and (SR &gt; 10.5)<br><br>[1.0] (REFMNG &gt; 6.5) and (SR &gt; 4.5) and (REFMNG &gt; 15.5) and (SR &gt; 9.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>197</td>
#       <td>[1.0] (REFMNG &gt; 6.5) and (SR &gt; 4.5) and (REFMNG &lt;= 15.5) and (SR &lt;= 10.5) and (REFMNG &gt; 11.5)<br><br>[0.58] (REFMNG &gt; 6.5) and (SR &gt; 4.5) and (REFMNG &gt; 15.5) and (SR &lt;= 9.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>169</td>
#       <td>[0.5370370370370371] (REFMNG &gt; 6.5) and (SR &lt;= 4.5) and (REFMNG &lt;= 10.5)<br><br>[0.9790209790209791] (REFMNG &gt; 6.5) and (SR &lt;= 4.5) and (REFMNG &gt; 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>103</td>
#       <td>[0.5733333333333334] (REFMNG &lt;= 6.5) and (SR &gt; 2.5)<br><br>[0.5147058823529411] (REFMNG &gt; 6.5) and (SR &gt; 4.5) and (REFMNG &lt;= 15.5) and (SR &lt;= 10.5) and (REFMNG &lt;= 11.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>135</td>
#       <td>[0.7868852459016393] (SR &lt;= 3.5) and (RELMNG &gt; 8.0)<br><br>[0.9487179487179487] (SR &gt; 3.5) and (RELMNG &gt; 11.0) and (RELMNG &lt;= 25.5) and (RELMNG &lt;= 16.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>331</td>
#       <td>[1.0] (SR &lt;= 3.5) and (RELMNG &lt;= 8.0)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>80</td>
#       <td>[0.9857142857142858] (SR &gt; 3.5) and (RELMNG &gt; 11.0) and (RELMNG &gt; 25.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>173</td>
#       <td>[0.9402173913043478] (SR &gt; 3.5) and (RELMNG &lt;= 11.0)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>181</td>
#       <td>[0.93048128342246] (SR &gt; 3.5) and (RELMNG &gt; 11.0) and (RELMNG &lt;= 25.5) and (RELMNG &gt; 16.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'REFMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>160</td>
#       <td>[0.6379310344827587] (REFMNG &gt; 5.5) and (REFMNG &gt; 13.5) and (GU &lt;= 12.5) and (GU &lt;= 8.5)<br><br>[1.0] (REFMNG &gt; 5.5) and (REFMNG &gt; 13.5) and (GU &lt;= 12.5) and (GU &gt; 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>239</td>
#       <td>[0.9830508474576272] (REFMNG &lt;= 5.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>254</td>
#       <td>[0.4675324675324675] (REFMNG &gt; 5.5) and (REFMNG &lt;= 13.5) and (GU &lt;= 9.5)<br><br>[0.9437229437229437] (REFMNG &gt; 5.5) and (REFMNG &lt;= 13.5) and (GU &gt; 9.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>190</td>
#       <td>[1.0] (REFMNG &gt; 5.5) and (REFMNG &gt; 13.5) and (GU &gt; 12.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>57</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>188</td>
#       <td>[0.9113300492610837] (RELMNG &gt; 9.5) and (RELMNG &gt; 17.5) and (RELMNG &lt;= 26.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>249</td>
#       <td>[0.6896551724137931] (RELMNG &lt;= 9.5) and (GU &lt;= 10.5) and (RELMNG &gt; 2.5) and (GU &gt; 8.5)<br><br>[0.9808612440191388] (RELMNG &lt;= 9.5) and (GU &gt; 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>259</td>
#       <td>[1.0] (RELMNG &lt;= 9.5) and (GU &lt;= 10.5) and (RELMNG &lt;= 2.5)<br><br>[1.0] (RELMNG &lt;= 9.5) and (GU &lt;= 10.5) and (RELMNG &gt; 2.5) and (GU &lt;= 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>129</td>
#       <td>[0.940677966101695] (RELMNG &gt; 9.5) and (RELMNG &lt;= 17.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>75</td>
#       <td>[1.0] (RELMNG &gt; 9.5) and (RELMNG &gt; 17.5) and (RELMNG &gt; 26.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['REFMNG', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>129</td>
#       <td>[0.9772727272727273] (REFMNG &gt; 6.5) and (RELMNG &gt; 8.5) and (RELMNG &lt;= 17.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>260</td>
#       <td>[1.0] (REFMNG &lt;= 6.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>206</td>
#       <td>[1.0] (REFMNG &gt; 6.5) and (RELMNG &gt; 8.5) and (RELMNG &gt; 17.5) and (RELMNG &lt;= 26.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>230</td>
#       <td>[0.9871244635193133] (REFMNG &gt; 6.5) and (RELMNG &lt;= 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>75</td>
#       <td>[1.0] (REFMNG &gt; 6.5) and (RELMNG &gt; 8.5) and (RELMNG &gt; 17.5) and (RELMNG &gt; 26.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Silhouette and Dunn for K-means

# %%
lc=list(df.columns)
lc2=lc.copy()
silhlist2=[]

for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        aa1=lc.index(n1)
        aa2=lc.index(n2)
        name2=str(n1 +' and '+n2)
        xatt2=df.iloc[:,lambda df: [aa1, aa2]]
        xattsm=dfsm.iloc[:,lambda dfsm: [aa1, aa2]]
        
        kmeanssm = KMeans(numk)
        kmeanssm.fit(xattsm)
        kmeans1 = KMeans(numk)
        kmeans1.fit(xatt2)
        
        scoresm = metrics.silhouette_score(xatt2, kmeans1.labels_, metric='euclidean')
        scoresm=round(scoresm,4)
        scoresmsm = metrics.silhouette_score(xattsm, kmeanssm.labels_, metric='euclidean')
        scoresmsm=round(scoresmsm,4)
        silhitem=[name2,scoresm,scoresmsm]
        silhlist2.append(silhitem)

silhdf2 = pd.DataFrame(silhlist2, columns =['Attributes','Silhouetter Score','Sampling Silhouetter Score'])
silhdf2.sort_values(by='Silhouetter Score',ascending=False)
# Out:
#           Attributes  Silhouetter Score  Sampling Silhouetter Score
# 5  REFMNG and RELMNG             0.4943                      0.5023
# 2      SR and RELMNG             0.4524                      0.4660
# 3      GU and REFMNG             0.4231                      0.4345
# 1      SR and REFMNG             0.4158                      0.4276
# 0          SR and GU             0.3732                      0.3950
# 4      GU and RELMNG             0.3709                      0.3953

# %% [markdown]
# # Dunn Index

# %%
from sklearn.metrics.pairwise import euclidean_distances

lc=list(df.columns)
lc2=lc.copy()
dunnlist=[]
diameter_method='farthest'
cdist_method='nearest'


for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        aa1=lc.index(n1)
        aa2=lc.index(n2)
        name2=str(n1 +' and '+n2)
        xatt2=df.iloc[:,lambda df: [aa1, aa2]]
        kmeans1 = KMeans(numk)
        k = kmeans1.fit_predict(xatt2)
        d = euclidean_distances(xatt2)
        dunk = dunn(k, d, diameter_method, cdist_method)
        dunk=round(dunk*10,4)
        
        xattsm=dfsm.iloc[:,lambda dfsm: [aa1, aa2]]
        kmeanssm = KMeans(numk)
        ksm = kmeanssm.fit_predict(xattsm)
        dsm = euclidean_distances(xattsm)
        dunksm = dunn(ksm, dsm, diameter_method, cdist_method)
        dunksm=round(dunksm*10,4)
        
        dunnitem=[name2,dunk,dunksm]
        dunnlist.append(dunnitem)

dunndf = pd.DataFrame(dunnlist, columns =['Attributes','DunnIndex','Sampling DunnIndex'])
dunndf.sort_values(by='DunnIndex',ascending=False).head(10)
# Out:
#           Attributes  DunnIndex  Sampling DunnIndex
# 1      SR and REFMNG     0.7981              0.7809
# 0          SR and GU     0.7692              0.8085
# 5  REFMNG and RELMNG     0.7495              0.7495
# 3      GU and REFMNG     0.6143              0.6143
# 4      GU and RELMNG     0.5019              0.5852
# 2      SR and RELMNG     0.4994              0.4994

# %% [markdown]
# # Hierarchical

# %%
linked = linkage(xattsm1, 'complete') 
dendrogram(linked, orientation='top', distance_sort='ascending', show_leaf_counts=False,color_threshold=15.0) 
plt.show()

# %%
modelac = AgglomerativeClustering(n_clusters=numk, linkage='complete')
modelac.fit(xatt)

aclabel = modelac.fit_predict(xatt)

scoresm = metrics.silhouette_score(xatt, modelac.labels_, metric='euclidean')

d = euclidean_distances(xatt)
diameter_method='farthest'
cdist_method='nearest'
dunk = dunn(aclabel, d, diameter_method, cdist_method)

print(scoresm,dunk)


fig, ax = plt.subplots() 
plt.scatter(df.iloc[:,a1], df.iloc[:,a2], c=modelac.labels_)
# Out:
# 0.42254321145249607 0.06063390625908324

# %% [markdown]
# # 300

# %%
#data=300

lc=list(df.columns)
lc2=lc.copy()

ahsilhlist=[]


for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        aa1=lc.index(n1)
        aa2=lc.index(n2)
        xatt2=df.iloc[:,lambda df: [aa1, aa2]]
        modelac2 = AgglomerativeClustering(n_clusters=numk, linkage='complete')
        modelac2.fit(xatt2)
        yac=modelac2.fit_predict(xatt2)

        cluster_report(xatt2, yac, min_samples_leaf=50, pruning_level=0.01)
        
        fig, ax = plt.subplots()
        scatter=plt.scatter(df.iloc[:,aa1], df.iloc[:,aa2], c=yac) 
        plt.title('Hierarchical Clustering with data=300: '+n1 + ' vs '+ n2)
        plt.xlabel(lc[lc.index(n1)])
        plt.ylabel(lc2[lc2.index(n2)])
        plt.colorbar(scatter)
        plt.show()
# Out:
# Index(['SR', 'GU'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>170</td>
#       <td>[0.9520958083832335] (SR &lt;= 10.5) and (GU &gt; 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>57</td>
#       <td>[0.7424242424242424] (SR &gt; 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>47</td>
#       <td>[0.7014925373134329] (SR &lt;= 10.5) and (GU &lt;= 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>10</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>16</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'REFMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>86</td>
#       <td>[0.9880952380952381] (REFMNG &lt;= 7.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>71</td>
#       <td>[0.7710843373493976] (REFMNG &gt; 7.5) and (SR &gt; 4.5) and (REFMNG &lt;= 15.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>66</td>
#       <td>[0.9682539682539683] (REFMNG &gt; 7.5) and (SR &lt;= 4.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>17</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>60</td>
#       <td>[0.8142857142857143] (REFMNG &gt; 7.5) and (SR &gt; 4.5) and (REFMNG &gt; 15.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>166</td>
#       <td>[0.9940119760479041] (RELMNG &lt;= 11.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>63</td>
#       <td>[0.7160493827160493] (RELMNG &gt; 11.5) and (SR &gt; 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>20</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>10</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>41</td>
#       <td>[0.7115384615384616] (RELMNG &gt; 11.5) and (SR &lt;= 8.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'REFMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>86</td>
#       <td>[0.8764044943820225] (REFMNG &gt; 11.5) and (GU &lt;= 12.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>59</td>
#       <td>[0.8125] (REFMNG &lt;= 11.5) and (REFMNG &gt; 5.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>78</td>
#       <td>[1.0] (REFMNG &gt; 11.5) and (GU &gt; 12.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>17</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>60</td>
#       <td>[0.7733333333333333] (REFMNG &lt;= 11.5) and (REFMNG &lt;= 5.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>134</td>
#       <td>[0.9689922480620154] (RELMNG &lt;= 5.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>55</td>
#       <td>[0.7727272727272727] (RELMNG &gt; 5.5) and (RELMNG &lt;= 15.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>39</td>
#       <td>[0.5] (RELMNG &gt; 5.5) and (RELMNG &gt; 15.5) and (RELMNG &lt;= 23.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>44</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>28</td>
#       <td>[0.5283018867924528] (RELMNG &gt; 5.5) and (RELMNG &gt; 15.5) and (RELMNG &gt; 23.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['REFMNG', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>96</td>
#       <td>[0.9578947368421052] (REFMNG &lt;= 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>70</td>
#       <td>[0.9305555555555556] (REFMNG &gt; 8.5) and (RELMNG &lt;= 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>57</td>
#       <td>[0.95] (REFMNG &gt; 8.5) and (RELMNG &gt; 10.5) and (RELMNG &gt; 22.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>36</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>41</td>
#       <td>[0.5616438356164384] (REFMNG &gt; 8.5) and (RELMNG &gt; 10.5) and (RELMNG &lt;= 22.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 600

# %%
#--------------------------------------data=600---------------------------------------------

lcsm=list(dfsm.columns)
lc2sm=lcsm.copy()

ahsilhsmlist=[]

for n1 in lcsm:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2sm.remove(n1)
    for n2 in lc2sm:
        aa1=lcsm.index(n1)
        aa2=lcsm.index(n2)
        xattsm=dfsm.iloc[:,lambda dfsm: [aa1, aa2]]
        modelacsm = AgglomerativeClustering(n_clusters=numk, linkage='complete')
        modelacsm.fit(xattsm)
        identified_clusters = modelacsm.fit_predict(xattsm)
        
        cluster_report(xattsm, identified_clusters, min_samples_leaf=50, pruning_level=0.01)
        
        fig, ax = plt.subplots()
        scatter=ax.scatter(dfsm.iloc[:,aa1], dfsm.iloc[:,aa2], c=modelacsm.labels_)
        plt.title('Hierarchical Clustering with data=600: '+n1 + ' vs '+ n2)
        plt.xlabel(lcsm[lcsm.index(n1)])
        plt.ylabel(lc2sm[lc2sm.index(n2)])
        plt.colorbar(scatter)
        plt.show()
# Out:
# Index(['SR', 'GU'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>167</td>
#       <td>[0.9272727272727272] (SR &lt;= 7.5) and (GU &lt;= 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>202</td>
#       <td>[1.0] (SR &gt; 7.5) and (GU &gt; 13.5) and (SR &lt;= 11.5)<br><br>[0.5357142857142857] (SR &gt; 7.5) and (GU &gt; 13.5) and (SR &gt; 11.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>362</td>
#       <td>[1.0] (SR &lt;= 7.5) and (GU &gt; 8.5) and (SR &lt;= 4.5)<br><br>[0.5338983050847458] (SR &lt;= 7.5) and (GU &gt; 8.5) and (SR &gt; 4.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>141</td>
#       <td>[0.4470588235294118] (SR &gt; 7.5) and (GU &lt;= 13.5) and (SR &lt;= 10.5)<br><br>[0.8899082568807339] (SR &gt; 7.5) and (GU &lt;= 13.5) and (SR &gt; 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>28</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'REFMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>230</td>
#       <td>[1.0] (REFMNG &lt;= 4.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>253</td>
#       <td>[0.9060150375939849] (REFMNG &gt; 4.5) and (SR &lt;= 7.5) and (REFMNG &lt;= 13.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>278</td>
#       <td>[0.9518072289156626] (REFMNG &gt; 4.5) and (SR &gt; 7.5) and (SR &lt;= 13.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>100</td>
#       <td>[0.92] (REFMNG &gt; 4.5) and (SR &lt;= 7.5) and (REFMNG &gt; 13.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>39</td>
#       <td>[0.5416666666666666] (REFMNG &gt; 4.5) and (SR &gt; 7.5) and (SR &gt; 13.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>453</td>
#       <td>[1.0] (RELMNG &lt;= 16.5) and (SR &lt;= 3.5)<br><br>[0.8969072164948454] (RELMNG &lt;= 16.5) and (SR &gt; 3.5) and (RELMNG &gt; 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>177</td>
#       <td>[0.9438202247191011] (RELMNG &gt; 16.5) and (SR &gt; 6.5) and (RELMNG &lt;= 27.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>46</td>
#       <td>[0.8518518518518519] (RELMNG &gt; 16.5) and (SR &lt;= 6.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>171</td>
#       <td>[1.0] (RELMNG &lt;= 16.5) and (SR &gt; 3.5) and (RELMNG &lt;= 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>53</td>
#       <td>[0.9137931034482759] (RELMNG &gt; 16.5) and (SR &gt; 6.5) and (RELMNG &gt; 27.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'REFMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>151</td>
#       <td>[0.9375] (REFMNG &gt; 6.5) and (REFMNG &gt; 13.5) and (GU &lt;= 11.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>300</td>
#       <td>[0.9024390243902439] (REFMNG &gt; 6.5) and (REFMNG &lt;= 13.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>187</td>
#       <td>[0.611764705882353] (REFMNG &gt; 6.5) and (REFMNG &gt; 13.5) and (GU &gt; 11.5) and (REFMNG &lt;= 15.5)<br><br>[1.0] (REFMNG &gt; 6.5) and (REFMNG &gt; 13.5) and (GU &gt; 11.5) and (REFMNG &gt; 15.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>19</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>243</td>
#       <td>[0.9455252918287937] (REFMNG &lt;= 6.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>410</td>
#       <td>[1.0] (RELMNG &lt;= 5.5) and (GU &lt;= 11.5)<br><br>[0.6707317073170732] (RELMNG &lt;= 5.5) and (GU &gt; 11.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>180</td>
#       <td>[0.4423076923076923] (RELMNG &gt; 5.5) and (RELMNG &lt;= 15.5) and (GU &lt;= 10.5)<br><br>[1.0] (RELMNG &gt; 5.5) and (RELMNG &lt;= 15.5) and (GU &gt; 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>95</td>
#       <td>[0.9540229885057471] (RELMNG &gt; 5.5) and (RELMNG &gt; 15.5) and (RELMNG &lt;= 27.5) and (GU &lt;= 11.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>142</td>
#       <td>[0.9788732394366197] (RELMNG &gt; 5.5) and (RELMNG &gt; 15.5) and (RELMNG &lt;= 27.5) and (GU &gt; 11.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>73</td>
#       <td>[1.0] (RELMNG &gt; 5.5) and (RELMNG &gt; 15.5) and (RELMNG &gt; 27.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['REFMNG', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>336</td>
#       <td>[0.9733333333333334] (REFMNG &lt;= 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>198</td>
#       <td>[0.5643564356435643] (REFMNG &gt; 8.5) and (RELMNG &lt;= 12.5) and (REFMNG &lt;= 11.5)<br><br>[0.9025974025974026] (REFMNG &gt; 8.5) and (RELMNG &lt;= 12.5) and (REFMNG &gt; 11.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>74</td>
#       <td>[0.9866666666666667] (REFMNG &gt; 8.5) and (RELMNG &gt; 12.5) and (RELMNG &gt; 26.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>209</td>
#       <td>[0.9521531100478469] (REFMNG &gt; 8.5) and (RELMNG &gt; 12.5) and (RELMNG &lt;= 26.5) and (RELMNG &gt; 16.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>83</td>
#       <td>[0.9508196721311475] (REFMNG &gt; 8.5) and (RELMNG &gt; 12.5) and (RELMNG &lt;= 26.5) and (RELMNG &lt;= 16.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Silhouette and Dunn AC

# %%
#Silhouette

lc=list(df.columns)
lc2=lc.copy()
ahsilhlist=[]

for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        aa1=lc.index(n1)
        aa2=lc.index(n2)
        name2=str(n1 +' and '+n2)
        xatt2=df.iloc[:,lambda df: [aa1, aa2]]
        
        xatt2=df.iloc[:,lambda df: [aa1, aa2]]
        modelac2 = AgglomerativeClustering(n_clusters=numk, linkage='complete')
        modelac2.fit(xatt2)
        ahscoresm = metrics.silhouette_score(xatt2, modelac2.labels_, metric='euclidean')
        ahscoresm=round(ahscoresm,4)
        
        xattsm=dfsm.iloc[:,lambda dfsm: [aa1, aa2]]
        modelacsm = AgglomerativeClustering(n_clusters=numk, linkage='complete')
        modelacsm.fit(xattsm)
        ahscoresmsm = metrics.silhouette_score(xattsm, modelacsm.labels_, metric='euclidean')
        ahscoresmsm=round(ahscoresmsm,4)
        
        ahsilhitem=[name2,ahscoresm,ahscoresmsm]
        ahsilhlist.append(ahsilhitem)

ahsilhdf2 = pd.DataFrame(ahsilhlist, columns =['Attributes','Silhouetter Score','Sampling Silhouetter Score'])
ahsilhdf2.sort_values(by='Silhouetter Score',ascending=False,ignore_index=True)
# Out:
#           Attributes  Silhouetter Score  Sampling Silhouetter Score
# 0      SR and RELMNG             0.4709                      0.2947
# 1      SR and REFMNG             0.4336                      0.3979
# 2  REFMNG and RELMNG             0.4266                      0.4057
# 3      GU and RELMNG             0.4225                      0.4445
# 4      GU and REFMNG             0.3126                      0.4062
# 5          SR and GU             0.2244                      0.2982

# %%
#dunnindex Hierarchical


from sklearn.metrics.pairwise import euclidean_distances

lc=list(df.columns)
lc2=lc.copy()
acdunnlist=[]
diameter_method='farthest'
cdist_method='nearest'

for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        aa1=lc.index(n1)
        aa2=lc.index(n2)
        name2=str(n1 +' and '+n2)
        xatt2=df.iloc[:,lambda df: [aa1, aa2]]
        modelac2 = AgglomerativeClustering(n_clusters=numk, linkage='complete')
        k = modelac2.fit_predict(xatt2)
        d = euclidean_distances(xatt2)
        acdunk = dunn(k, d, diameter_method, cdist_method)
        acdunk = round(acdunk*10,4)
        
        
        xatt2sm=dfsm.iloc[:,lambda df: [aa1, aa2]]
        modelac2sm = AgglomerativeClustering(n_clusters=numk, linkage='complete')
        ksm = modelac2sm.fit_predict(xatt2sm)
        dsm = euclidean_distances(xatt2sm)
        acsmdunk = dunn(ksm, dsm, diameter_method, cdist_method)
        acsmdunk = round(acsmdunk*10,4)
        
        acdunnitem=[name2,acdunk,acsmdunk]
        acdunnlist.append(acdunnitem)

acdunndf = pd.DataFrame(acdunnlist, columns =['Attributes','DunnIndex','Sampling DunnIndex'])
acdunndf.sort_values(by='DunnIndex',ascending=False).head(10)
# Out:
#           Attributes  DunnIndex  Sampling DunnIndex
# 1      SR and REFMNG     0.8085              0.8085
# 0          SR and GU     0.7692              0.7670
# 3      GU and REFMNG     0.7352              0.7352
# 2      SR and RELMNG     0.7284              0.5178
# 5  REFMNG and RELMNG     0.6934              0.6727
# 4      GU and RELMNG     0.6063              0.6143
