# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import time 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support 
# %matplotlib inline
from IPython.display import display
from six import StringIO
from matplotlib import pyplot as plt
from matplotlib.lines import Line2D

from scipy.stats import pearsonr

from sklearn.cluster import KMeans 
from sklearn import metrics
from sklearn.metrics import pairwise_distances

from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering

# %%
import numpy as np
import pandas as pd 
from sklearn.preprocessing import LabelEncoder

DIAMETER_METHODS = ['mean_cluster', 'farthest']
CLUSTER_DISTANCE_METHODS = ['nearest', 'farthest']


def inter_cluster_distances(labels, distances, method='nearest'):
  
    if method not in CLUSTER_DISTANCE_METHODS:
        raise ValueError(
            'method must be one of {}'.format(CLUSTER_DISTANCE_METHODS))

    if method == 'nearest':
        return __cluster_distances_by_points(labels, distances)
    elif method == 'farthest':
        return __cluster_distances_by_points(labels, distances, farthest=True)


def __cluster_distances_by_points(labels, distances, farthest=False):
    n_unique_labels = len(np.unique(labels))
    cluster_distances = np.full((n_unique_labels, n_unique_labels),
                                float('inf') if not farthest else 0)

    np.fill_diagonal(cluster_distances, 0)

    for i in np.arange(0, len(labels) - 1):
        for ii in np.arange(i, len(labels)):
            if labels[i] != labels[ii] and (
                (not farthest and
                 distances[i, ii] < cluster_distances[labels[i], labels[ii]])
                    or
                (farthest and
                 distances[i, ii] > cluster_distances[labels[i], labels[ii]])):
                cluster_distances[labels[i], labels[ii]] = cluster_distances[
                    labels[ii], labels[i]] = distances[i, ii]
    return cluster_distances


def diameter(labels, distances, method='farthest'):
   
    if method not in DIAMETER_METHODS:
        raise ValueError('method must be one of {}'.format(DIAMETER_METHODS))

    n_clusters = len(np.unique(labels))
    diameters = np.zeros(n_clusters)

    if method == 'mean_cluster':
        for i in range(0, len(labels) - 1):
            for ii in range(i + 1, len(labels)):
                if labels[i] == labels[ii]:
                    diameters[labels[i]] += distances[i, ii]

        for i in range(len(diameters)):
            diameters[i] /= sum(labels == i)

    elif method == 'farthest':
        for i in range(0, len(labels) - 1):
            for ii in range(i + 1, len(labels)):
                if labels[i] == labels[ii] and distances[i, ii] > diameters[
                        labels[i]]:
                    diameters[labels[i]] = distances[i, ii]
    return diameters


def dunn(labels, distances, diameter_method='farthest',
         cdist_method='nearest'):
    

    labels = LabelEncoder().fit(labels).transform(labels)

    ic_distances = inter_cluster_distances(labels, distances, cdist_method)
    min_distance = min(ic_distances[ic_distances.nonzero()])
    max_diameter = max(diameter(labels, distances, diameter_method))

    return min_distance / max_diameter

# %%
from IPython.display import display, HTML
from sklearn.tree import _tree, DecisionTreeClassifier
import pandas as pd

def pretty_print(df):
    return display( HTML( df.to_html().replace("\\n","<br>") ) )

def get_class_rules(tree: DecisionTreeClassifier, feature_names: list):
    inner_tree: _tree.Tree = tree.tree_
    classes = tree.classes_
    class_rules_dict = dict()
    
    
    def tree_dfs(node_id=0, current_rule=[]):
        split_feature = inner_tree.feature[node_id]
        if split_feature != _tree.TREE_UNDEFINED: # internal node
            name = feature_names[split_feature]
            threshold = inner_tree.threshold[node_id]
      # left child
            left_rule = current_rule + ["{} <= {}".format(name, threshold)]
            tree_dfs(inner_tree.children_left[node_id], left_rule)
      # right child
            right_rule = current_rule + ["{} > {}".format(name, threshold)]
            tree_dfs(inner_tree.children_right[node_id], right_rule)
        else: # leaf
            dist = inner_tree.value[node_id][0]
            dist = dist/dist.sum()
            max_idx = dist.argmax()
            if len(current_rule) == 0:
                rule_string = "ALL"
            else:
                rule_string = " and ".join(current_rule)
      # register new rule to dictionary
            selected_class = classes[max_idx]
            class_probability = dist[max_idx]
            class_rules = class_rules_dict.get(selected_class, [])
            class_rules.append((rule_string, class_probability))
            class_rules_dict[selected_class] = class_rules
    
    tree_dfs() # start from root, node_id = 0
    return class_rules_dict

def cluster_report(data: pd.DataFrame, clusters, min_samples_leaf=50, pruning_level=0.01):
    tree = DecisionTreeClassifier(min_samples_leaf=min_samples_leaf, ccp_alpha=pruning_level)
    tree.fit(data, clusters)
    
    # Generate Report
    feature_names = data.columns
    class_rule_dict = get_class_rules(tree, feature_names)

    report_class_list = []
    for class_name in class_rule_dict.keys():
        rule_list = class_rule_dict[class_name]
        combined_string = ""
        for rule in rule_list:
            combined_string += "[{}] {}\n\n".format(rule[1], rule[0])
        report_class_list.append((class_name, combined_string))
        
    cluster_instance_df = pd.Series(clusters).value_counts().reset_index()
    cluster_instance_df.columns = ['class_name', 'instance_count']
    report_df = pd.DataFrame(report_class_list, columns=['class_name', 'rule_list'])
    report_df = pd.merge(cluster_instance_df, report_df, on='class_name', how='left')
    print(feature_names)
    pretty_print(report_df.sort_values(by='class_name')[['class_name', 'instance_count', 'rule_list']])

# %%
dataf=pd.read_csv('FULL DATA.csv')

dataf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   AGEGROUP     300 non-null    int64
#  1   ageinmonths  300 non-null    int64
#  2   PV           300 non-null    int64
#  3   SR           300 non-null    int64
#  4   GU           300 non-null    int64
#  5   REFMNG       300 non-null    int64
#  6   RELMNG       300 non-null    int64
#  7   EL           300 non-null    int64
#  8   TOTAL        300 non-null    int64
# dtypes: int64(9)
# memory usage: 21.2 KB

# %% [markdown]
# # Peason correlation

# %%
dataf.corr(method = 'pearson', min_periods = 1)
# Out:
#              AGEGROUP  ageinmonths        PV        SR        GU    REFMNG  \
# AGEGROUP     1.000000     0.989484  0.760785  0.744749  0.550699  0.791940
# ageinmonths  0.989484     1.000000  0.770036  0.753923  0.542752  0.799050
# PV           0.760785     0.770036  1.000000  0.647086  0.556428  0.647359
# SR           0.744749     0.753923  0.647086  1.000000  0.394013  0.619371
# GU           0.550699     0.542752  0.556428  0.394013  1.000000  0.356654
# REFMNG       0.791940     0.799050  0.647359  0.619371  0.356654  1.000000
# RELMNG       0.818825     0.823412  0.594285  0.645616  0.428535  0.693055
# EL           0.815002     0.809715  0.668376  0.650380  0.538894  0.606768
# TOTAL        0.938661     0.942078  0.819717  0.805296  0.613950  0.812597
#
#                RELMNG        EL     TOTAL
# AGEGROUP     0.818825  0.815002  0.938661
# ageinmonths  0.823412  0.809715  0.942078
# PV           0.594285  0.668376  0.819717
# SR           0.645616  0.650380  0.805296
# GU           0.428535  0.538894  0.613950
# REFMNG       0.693055  0.606768  0.812597
# RELMNG       1.000000  0.680759  0.872470
# EL           0.680759  1.000000  0.871268
# TOTAL        0.872470  0.871268  1.000000

# %%
lc=list(dataf.columns)
lc2=lc.copy()
pcclist=[]

minscore=2
maxscore=0

for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        list1 = dataf[lc[lc.index(n1)]]
        list2 = dataf[lc2[lc2.index(n2)]]
        corr, _ = pearsonr(list1, list2)
        name2=str(n1 +' and '+n2)
        pccitem=[name2,corr]
        pcclist.append(pccitem)
        #print(name2)
        #print(n1 +' and '+ n2 + ' is : %.3f' % corr)
        #plt.scatter(dataf[lc[lc.index(n1)]], dataf[lc2[lc2.index(n2)]])
        if corr< minscore:
            minscore=corr
            minatr1=n1
            minatr2=n2
        if corr> maxscore:
            maxscore=corr
            maxatr1=n1
            maxatr2=n2

print(minatr1 +' and '+ minatr2 + ' is : %.3f' % minscore)
print(maxatr1 +' and '+ maxatr2 + ' is : %.3f' % maxscore)
# Out:
# GU and REFMNG is : 0.357
# AGEGROUP and ageinmonths is : 0.989

# %%
pccdf = pd.DataFrame(pcclist, columns =['Attributes', 'Correlation'])

pccdf.sort_values(by='Correlation')
# Out:
#                   Attributes  Correlation
# 26             GU and REFMNG     0.356654
# 21                 SR and GU     0.394013
# 27             GU and RELMNG     0.428535
# 28                 GU and EL     0.538894
# 10        ageinmonths and GU     0.542752
# 3            AGEGROUP and GU     0.550699
# 16                 PV and GU     0.556428
# 18             PV and RELMNG     0.594285
# 31             REFMNG and EL     0.606768
# 29              GU and TOTAL     0.613950
# 22             SR and REFMNG     0.619371
# 23             SR and RELMNG     0.645616
# 15                 PV and SR     0.647086
# 17             PV and REFMNG     0.647359
# 24                 SR and EL     0.650380
# 19                 PV and EL     0.668376
# 33             RELMNG and EL     0.680759
# 30         REFMNG and RELMNG     0.693055
# 2            AGEGROUP and SR     0.744749
# 9         ageinmonths and SR     0.753923
# 1            AGEGROUP and PV     0.760785
# 8         ageinmonths and PV     0.770036
# 4        AGEGROUP and REFMNG     0.791940
# 11    ageinmonths and REFMNG     0.799050
# 25              SR and TOTAL     0.805296
# 13        ageinmonths and EL     0.809715
# 32          REFMNG and TOTAL     0.812597
# 6            AGEGROUP and EL     0.815002
# 5        AGEGROUP and RELMNG     0.818825
# 20              PV and TOTAL     0.819717
# 12    ageinmonths and RELMNG     0.823412
# 35              EL and TOTAL     0.871268
# 34          RELMNG and TOTAL     0.872470
# 7         AGEGROUP and TOTAL     0.938661
# 14     ageinmonths and TOTAL     0.942078
# 0   AGEGROUP and ageinmonths     0.989484

# %%
print(dataf.var())
# Out:
# AGEGROUP          2.926421
# ageinmonths     107.581839
# PV               30.583099
# SR               26.069967
# GU               14.255017
# REFMNG           35.382598
# RELMNG          104.943266
# EL               81.527313
# TOTAL          1074.694437
# dtype: float64

# %%
from sklearn.feature_selection import VarianceThreshold

vhold=VarianceThreshold(threshold=50)
vhold.fit(dataf)
vhold.get_support()
# Out:
# array([False,  True, False, False, False, False,  True,  True,  True])

# %% [markdown]
# # Drop features

# %%
df=dataf.drop(['AGEGROUP', 'ageinmonths','TOTAL','PV'], axis = 1)
df.head()
# Out:
#    SR  GU  REFMNG  RELMNG  EL
# 0   0   3       8       4   2
# 1   0   6       1       4   0
# 2   5   7       0       2   0
# 3   2  11       0       0   1
# 4   0  10       2       0   0

# %%
a1=2
a2=3
xatt=df.iloc[:,lambda df: [a1,a2]]
print(xatt)
# Out:
#      REFMNG  RELMNG
# 0         8       4
# 1         1       4
# 2         0       2
# 3         0       0
# 4         2       0
# ..      ...     ...
# 295      15      20
# 296      15      33
# 297      16      33
# 298      13      32
# 299      15      33
#
# [300 rows x 2 columns]

# %% [markdown]
# # Kmeans k=300

# %%
wcss=[]
prev=0

for i in range(2,12):
    kmeans = KMeans(i)
    kmeans.fit(xatt)
    wcss_iter = kmeans.inertia_
    if prev==0:
        prev=wcss_iter
    else:
        print(i-1,i,prev-wcss_iter)
        prev=wcss_iter
    wcss.append(wcss_iter)

number_clusters = range(2,12)
plt.plot(number_clusters,wcss)
plt.title('The Elbow title')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# 2 3 5621.757697135482
# 3 4 2460.2001891698465
# 4 5 1115.322360898725
# 5 6 659.9920291998442
# 6 7 390.44975746371165
# 7 8 280.72177210200107
# 8 9 254.86068938225617
# 9 10 172.60010340376107
# 10 11 167.7081274571069
# Text(0, 0.5, 'WCSS')

# %%
numk=6

# %% [markdown]
# # kmeas 300

# %%
kmean = KMeans(n_clusters = numk, init = "k-means++")
kmean.fit(xatt)

from sklearn.metrics.pairwise import euclidean_distances

labelkm = kmean.fit_predict(xatt)
scoresm = metrics.silhouette_score(xatt, kmean.labels_, metric='euclidean')

d = euclidean_distances(xatt)
diameter_method='farthest'
cdist_method='nearest'
dunkm = dunn(labelkm, d, diameter_method, cdist_method)

print(scoresm,dunkm)


fig, ax = plt.subplots() 
plt.scatter(xatt.iloc[:,0], xatt.iloc[:,1], c=kmean.labels_) 
plt.scatter(kmean.cluster_centers_[:,0], kmean.cluster_centers_[:,1],marker='x', color='red')
# Out:
# 0.4786117634568306 0.06726727939963124

# %%
ym= labelkm

# %%
ymean2= labelkm

cluster_report(xatt, ymean2, min_samples_leaf=50, pruning_level=0.01)
# Out:
# Index(['REFMNG', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>51</td>
#       <td>[0.8363636363636363] REFMNG &gt; 5.5 and RELMNG &lt;= 17.5 and REFMNG &lt;= 11.5<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>63</td>
#       <td>[0.6458333333333334] REFMNG &gt; 5.5 and RELMNG &gt; 17.5<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>46</td>
#       <td>[0.4864864864864865] REFMNG &gt; 5.5 and RELMNG &lt;= 17.5 and REFMNG &gt; 11.5<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>36</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4</td>
#       <td>32</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>5</td>
#       <td>72</td>
#       <td>[0.96] REFMNG &lt;= 5.5<br><br></td>
#     </tr>
#   </tbody>
# </table>

# %%
lc=list(df.columns)
lc2=lc.copy()
#silhlist=[]

for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        aa1=lc.index(n1)
        aa2=lc.index(n2)
        xatt2=df.iloc[:,lambda df: [aa1, aa2]]
        
        kmeans1 = KMeans(numk)
        kmeans1.fit(xatt2)
        identified_clusters = kmeans1.fit_predict(xatt2)
        
        scoresm = metrics.silhouette_score(xatt2, kmeans1.labels_, metric='euclidean')
        #silhitem=[lc[lc.index(n1)],lc2[lc2.index(n2)],scoresm]
        #silhlist.append(silhitem)
        
        cluster_report(xatt2, identified_clusters, min_samples_leaf=50, pruning_level=0.01)
        
        fig, ax = plt.subplots()
        scatter=plt.scatter(df.iloc[:,aa1], df.iloc[:,aa2], c=kmeans1.labels_) 
        plt.scatter(kmeans1.cluster_centers_[:,0], kmeans1.cluster_centers_[:,1],marker='x', color='red')
        plt.title('K-means Clustering data=300: '+lc[lc.index(n1)] + ' vs '+ lc2[lc2.index(n2)])
        #+ ' Silhouetter Score: %.3f' % scoresm
        plt.xlabel(lc[lc.index(n1)])
        plt.ylabel(lc2[lc2.index(n2)])
        plt.colorbar(scatter)
        plt.show()
# Out:
# Index(['SR', 'GU'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>82</td>
#       <td>[0.7047619047619048] (SR &lt;= 7.5) and (SR &gt; 1.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>47</td>
#       <td>[0.71875] (SR &gt; 7.5) and (GU &gt; 12.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>21</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>83</td>
#       <td>[0.8701298701298701] (SR &lt;= 7.5) and (SR &lt;= 1.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>46</td>
#       <td>[0.7962962962962963] (SR &gt; 7.5) and (GU &lt;= 12.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>21</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'REFMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>66</td>
#       <td>[0.7924528301886793] (REFMNG &gt; 4.5) and (SR &gt; 4.5) and (REFMNG &lt;= 16.5) and (SR &lt;= 8.5)<br><br>[0.4339622641509434] (REFMNG &gt; 4.5) and (SR &gt; 4.5) and (REFMNG &lt;= 16.5) and (SR &gt; 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>35</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2</td>
#       <td>20</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>66</td>
#       <td>[0.9552238805970149] (REFMNG &lt;= 4.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>61</td>
#       <td>[0.9230769230769231] (REFMNG &gt; 4.5) and (SR &gt; 4.5) and (REFMNG &gt; 16.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5</td>
#       <td>52</td>
#       <td>[0.6933333333333334] (REFMNG &gt; 4.5) and (SR &lt;= 4.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>101</td>
#       <td>[0.970873786407767] (RELMNG &lt;= 8.5) and (SR &lt;= 4.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>55</td>
#       <td>[0.5454545454545454] (RELMNG &gt; 8.5) and (RELMNG &gt; 18.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>58</td>
#       <td>[0.9803921568627451] (RELMNG &lt;= 8.5) and (SR &gt; 4.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3</td>
#       <td>14</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>48</td>
#       <td>[0.7931034482758621] (RELMNG &gt; 8.5) and (RELMNG &lt;= 18.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>24</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'EL'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>101</td>
#       <td>[0.8807339449541285] (EL &lt;= 3.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1</td>
#       <td>29</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>41</td>
#       <td>[0.41] (EL &gt; 3.5) and (EL &gt; 11.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>44</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>51</td>
#       <td>[0.5384615384615384] (EL &gt; 3.5) and (EL &lt;= 11.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>34</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'REFMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>76</td>
#       <td>[0.7755102040816326] (REFMNG &lt;= 13.5) and (REFMNG &gt; 6.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>41</td>
#       <td>[0.5061728395061729] (REFMNG &lt;= 13.5) and (REFMNG &lt;= 6.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>53</td>
#       <td>[0.8548387096774194] (REFMNG &gt; 13.5) and (GU &lt;= 12.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>67</td>
#       <td>[1.0] (REFMNG &gt; 13.5) and (GU &gt; 12.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4</td>
#       <td>24</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>39</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>30</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>121</td>
#       <td>[0.6481481481481481] (RELMNG &lt;= 6.5) and (GU &lt;= 8.5)<br><br>[1.0] (RELMNG &lt;= 6.5) and (GU &gt; 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>45</td>
#       <td>[0.5192307692307693] (RELMNG &gt; 6.5) and (RELMNG &gt; 15.5) and (RELMNG &lt;= 23.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>29</td>
#       <td>[0.5471698113207547] (RELMNG &gt; 6.5) and (RELMNG &gt; 15.5) and (RELMNG &gt; 23.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4</td>
#       <td>24</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>51</td>
#       <td>[0.8909090909090909] (RELMNG &gt; 6.5) and (RELMNG &lt;= 15.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'EL'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>70</td>
#       <td>[0.7555555555555555] (EL &lt;= 7.5) and (EL &lt;= 2.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>39</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>59</td>
#       <td>[0.7272727272727273] (EL &lt;= 7.5) and (EL &gt; 2.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>63</td>
#       <td>[0.9117647058823529] (EL &gt; 7.5) and (EL &lt;= 14.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4</td>
#       <td>29</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5</td>
#       <td>40</td>
#       <td>[0.5263157894736842] (EL &gt; 7.5) and (EL &gt; 14.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['REFMNG', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>72</td>
#       <td>[0.96] (REFMNG &lt;= 5.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>64</td>
#       <td>[0.65625] (REFMNG &gt; 5.5) and (RELMNG &gt; 17.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>46</td>
#       <td>[0.8181818181818182] (REFMNG &gt; 5.5) and (RELMNG &lt;= 17.5) and (RELMNG &gt; 7.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3</td>
#       <td>32</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>51</td>
#       <td>[0.5405405405405406] (REFMNG &gt; 5.5) and (RELMNG &lt;= 17.5) and (RELMNG &lt;= 7.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>35</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['REFMNG', 'EL'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>40</td>
#       <td>[0.5063291139240507] (REFMNG &gt; 6.5) and (EL &gt; 13.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>64</td>
#       <td>[0.8823529411764706] (REFMNG &gt; 6.5) and (EL &lt;= 13.5) and (EL &gt; 6.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>72</td>
#       <td>[0.8888888888888888] (REFMNG &lt;= 6.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>50</td>
#       <td>[0.4861111111111111] (REFMNG &gt; 6.5) and (EL &lt;= 13.5) and (EL &lt;= 6.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>41</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>33</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['RELMNG', 'EL'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>36</td>
#       <td>[0.6792452830188679] (EL &gt; 4.5) and (RELMNG &gt; 11.5) and (EL &gt; 17.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>51</td>
#       <td>[0.8596491228070176] (EL &gt; 4.5) and (RELMNG &lt;= 11.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>41</td>
#       <td>[0.44776119402985076] (EL &gt; 4.5) and (RELMNG &gt; 11.5) and (EL &lt;= 17.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>110</td>
#       <td>[1.0] (EL &lt;= 4.5) and (RELMNG &lt;= 2.5)<br><br>[0.7413793103448276] (EL &lt;= 4.5) and (RELMNG &gt; 2.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4</td>
#       <td>20</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>42</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # sampling

# %%
from sklearn.utils import resample

lendf= int(len(df))
doublelen=3*lendf

samsil=[]
samdun=[]

maxsil=0
maxdun=0
optimalsil=0
optimalsdun=0

diameter_method='farthest'
cdist_method='nearest'

for i in range (lendf,doublelen):
    dfsmloop = resample(xatt , n_samples=i)
    kmeansm = KMeans(numk)
    kmeansm.fit(dfsmloop)
    scoresmloop = metrics.silhouette_score(dfsmloop, kmeansm.labels_, metric='euclidean')
    samsil.append(scoresmloop)
    
    if scoresmloop > maxsil:
        optimalsil=i
        maxsil= scoresmloop
    
    labelkm = kmeansm.fit_predict(dfsmloop)
    d = euclidean_distances(dfsmloop)
    dunkm = dunn(labelkm, d, diameter_method, cdist_method)
    samdun.append(dunkm)
    
    if dunkm > maxdun:
        optimaldun=i
        maxdun=dunkm


print (optimalsil,maxsil)
print(optimaldun,maxdun)


number_sampling = range(lendf,doublelen)
plt.plot(number_sampling,samsil)
plt.title('Silhouette title')
plt.xlabel('Number of sample')
plt.ylabel('Silhouette score')
plt.show()

plt.plot(number_sampling,samdun)
plt.title('Dunn title')
plt.xlabel('Number of sample')
plt.ylabel('Dunn score')
plt.show()
# Out:
# 665 0.5076474111199232
# 312 0.08821621827824618

# %%
doublelen=int(2*len(df))
doublelen=doublelen+65

dfsm = resample(df , n_samples=doublelen)
dfsm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 665 entries, 68 to 243
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SR      665 non-null    int64
#  1   GU      665 non-null    int64
#  2   REFMNG  665 non-null    int64
#  3   RELMNG  665 non-null    int64
#  4   EL      665 non-null    int64
# dtypes: int64(5)
# memory usage: 31.2 KB

# %%
dfsm.corr(method = 'pearson', min_periods = 1)
# Out:
#               SR        GU    REFMNG    RELMNG        EL
# SR      1.000000  0.435418  0.618158  0.673689  0.661120
# GU      0.435418  1.000000  0.380350  0.485245  0.559793
# REFMNG  0.618158  0.380350  1.000000  0.696751  0.589196
# RELMNG  0.673689  0.485245  0.696751  1.000000  0.688200
# EL      0.661120  0.559793  0.589196  0.688200  1.000000

# %%
lc=list(dfsm.columns)
lc2=lc.copy()
pccsmlist=[]

minscore=2
maxscore=0

for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        list1 = dfsm[lc[lc.index(n1)]]
        list2 = dfsm[lc2[lc2.index(n2)]]
        corr, _ = pearsonr(list1, list2)
        name2=str(n1 +' and '+n2)
        pccsmitem=[name2,corr]
        pccsmlist.append(pccsmitem)
        #print(name2)
        #print(n1 +' and '+ n2 + ' is : %.3f' % corr)
        #plt.scatter(dataf[lc[lc.index(n1)]], dataf[lc2[lc2.index(n2)]])
        if corr< minscore:
            minscore=corr
            minatr1=n1
            minatr2=n2
        if corr> maxscore:
            maxscore=corr
            maxatr1=n1
            maxatr2=n2
            
pccsmdf = pd.DataFrame(pccsmlist, columns =['Attributes', 'Correlation'])
print(dfsm.var())
pccsmdf.sort_values(by='Correlation').head()
# Out:
# SR         26.189723
# GU         13.602740
# REFMNG     34.581656
# RELMNG    101.464136
# EL         84.650996
# dtype: float64
#       Attributes  Correlation
# 4  GU and REFMNG     0.343716
# 5  GU and RELMNG     0.379938
# 0      SR and GU     0.400867
# 6      GU and EL     0.535268
# 8  REFMNG and EL     0.619603

# %% [markdown]
# # k-means sampling

# %%
wcss=[]
prev=0
a1=2
a2=3
xattsm1=dfsm.iloc[:,lambda df: [a1,a2]]

for i in range(2,12):
    kmeans = KMeans(i)
    kmeans.fit(dfsm)
    wcss_iter = kmeans.inertia_
    if prev==0:
        prev=wcss_iter
    else:
        print(i-1,i,prev-wcss_iter)
        prev=wcss_iter
    wcss.append(wcss_iter)

number_clusters = range(2,12)
plt.plot(number_clusters,wcss)
plt.title('The Elbow title')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# 2 3 17042.413176194124
# 3 4 10461.527186458174
# 4 5 7713.092123537521
# 5 6 4756.2901468474665
# 6 7 2855.539125612806
# 7 8 2172.2124493633746
# 8 9 2125.355236416144
# 9 10 1559.5732090793608
# 10 11 1324.1008684151566
# Text(0, 0.5, 'WCSS')

# %%
lcsm=list(dfsm.columns)
lc2sm=lcsm.copy()

silhsmlist=[]

for n1 in lcsm:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2sm.remove(n1)
    for n2 in lc2sm:
        aa1=lcsm.index(n1)
        aa2=lcsm.index(n2)
        xattsm=dfsm.iloc[:,lambda datafsm: [aa1, aa2]]
        kmeanssm = KMeans(numk)
        kmeanssm.fit(xattsm)
        identified_clusters = kmeanssm.fit_predict(xattsm)
        
        cluster_report(xattsm, identified_clusters, min_samples_leaf=50, pruning_level=0.01)
        
        fig, ax = plt.subplots()
        scatter=plt.scatter(dfsm.iloc[:,aa1], dfsm.iloc[:,aa2], c=kmeanssm.labels_) 
        plt.scatter(kmeanssm.cluster_centers_[:,0], kmeanssm.cluster_centers_[:,1],marker='x', color='red')
        plt.title('K-means Clustering data=600: '+lcsm[lcsm.index(n1)] + ' vs '+ lc2sm[lc2sm.index(n2)])
        plt.xlabel(lcsm[lcsm.index(n1)])
        plt.ylabel(lc2sm[lc2sm.index(n2)])
        plt.colorbar(scatter)
        plt.show()
# Out:
# Index(['SR', 'GU'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>96</td>
#       <td>[0.9078947368421053] (SR &gt; 6.5) and (GU &gt; 12.5) and (SR &lt;= 11.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>183</td>
#       <td>[0.9585798816568047] (SR &lt;= 6.5) and (GU &lt;= 10.5) and (SR &lt;= 2.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>59</td>
#       <td>[0.48214285714285715] (SR &gt; 6.5) and (GU &lt;= 12.5) and (SR &gt; 11.5)<br><br>[0.5423728813559322] (SR &gt; 6.5) and (GU &gt; 12.5) and (SR &gt; 11.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>175</td>
#       <td>[0.35294117647058826] (SR &lt;= 6.5) and (GU &lt;= 10.5) and (SR &gt; 2.5)<br><br>[0.9536423841059603] (SR &lt;= 6.5) and (GU &gt; 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4</td>
#       <td>39</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>113</td>
#       <td>[0.9186046511627907] (SR &gt; 6.5) and (GU &lt;= 12.5) and (SR &lt;= 11.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'REFMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>0</td>
#       <td>39</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>109</td>
#       <td>[0.8412698412698413] (REFMNG &gt; 4.5) and (REFMNG &lt;= 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>141</td>
#       <td>[1.0] (REFMNG &gt; 4.5) and (REFMNG &gt; 10.5) and (SR &gt; 4.5) and (REFMNG &lt;= 15.5) and (SR &lt;= 9.5)<br><br>[0.5507246376811594] (REFMNG &gt; 4.5) and (REFMNG &gt; 10.5) and (SR &gt; 4.5) and (REFMNG &lt;= 15.5) and (SR &gt; 9.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>146</td>
#       <td>[0.9787234042553191] (REFMNG &lt;= 4.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>140</td>
#       <td>[0.8209876543209876] (REFMNG &gt; 4.5) and (REFMNG &gt; 10.5) and (SR &gt; 4.5) and (REFMNG &gt; 15.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>90</td>
#       <td>[1.0] (REFMNG &gt; 4.5) and (REFMNG &gt; 10.5) and (SR &lt;= 4.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>104</td>
#       <td>[0.967741935483871] (RELMNG &gt; 4.5) and (RELMNG &lt;= 11.5) and (SR &lt;= 4.5)<br><br>[0.5384615384615384] (RELMNG &gt; 4.5) and (RELMNG &lt;= 11.5) and (SR &gt; 4.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>97</td>
#       <td>[0.8829787234042553] (RELMNG &gt; 4.5) and (RELMNG &gt; 11.5) and (RELMNG &lt;= 18.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2</td>
#       <td>53</td>
#       <td>[0.9807692307692307] (RELMNG &gt; 4.5) and (RELMNG &gt; 11.5) and (RELMNG &gt; 18.5) and (RELMNG &gt; 27.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>69</td>
#       <td>[0.7377049180327869] (RELMNG &lt;= 4.5) and (SR &gt; 4.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>143</td>
#       <td>[0.891156462585034] (RELMNG &gt; 4.5) and (RELMNG &gt; 11.5) and (RELMNG &gt; 18.5) and (RELMNG &lt;= 27.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>5</td>
#       <td>199</td>
#       <td>[0.9847715736040609] (RELMNG &lt;= 4.5) and (SR &lt;= 4.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'EL'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>100</td>
#       <td>[1.0] (EL &gt; 3.5) and (EL &gt; 21.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>79</td>
#       <td>[0.9672131147540983] (EL &gt; 3.5) and (EL &lt;= 21.5) and (EL &lt;= 11.5) and (SR &gt; 7.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>129</td>
#       <td>[0.852112676056338] (EL &gt; 3.5) and (EL &lt;= 21.5) and (EL &lt;= 11.5) and (SR &lt;= 7.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>70</td>
#       <td>[0.9324324324324325] (EL &gt; 3.5) and (EL &lt;= 21.5) and (EL &gt; 11.5) and (SR &gt; 9.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4</td>
#       <td>68</td>
#       <td>[0.9454545454545454] (EL &gt; 3.5) and (EL &lt;= 21.5) and (EL &gt; 11.5) and (SR &lt;= 9.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>5</td>
#       <td>219</td>
#       <td>[1.0] (EL &lt;= 3.5) and (SR &lt;= 3.5)<br><br>[0.5892857142857143] (EL &lt;= 3.5) and (SR &gt; 3.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'REFMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>169</td>
#       <td>[0.5068493150684932] (REFMNG &gt; 7.5) and (REFMNG &lt;= 13.5) and (GU &lt;= 9.5)<br><br>[1.0] (REFMNG &gt; 7.5) and (REFMNG &lt;= 13.5) and (GU &gt; 9.5) and (GU &lt;= 12.5)<br><br>[0.6774193548387096] (REFMNG &gt; 7.5) and (REFMNG &lt;= 13.5) and (GU &gt; 9.5) and (GU &gt; 12.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>113</td>
#       <td>[0.8699186991869918] (REFMNG &lt;= 7.5) and (GU &lt;= 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>131</td>
#       <td>[1.0] (REFMNG &gt; 7.5) and (REFMNG &gt; 13.5) and (GU &gt; 12.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>73</td>
#       <td>[0.9076923076923077] (REFMNG &lt;= 7.5) and (GU &gt; 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>128</td>
#       <td>[0.847682119205298] (REFMNG &gt; 7.5) and (REFMNG &gt; 13.5) and (GU &lt;= 12.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>51</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>83</td>
#       <td>[0.8977272727272727] (RELMNG &gt; 8.5) and (RELMNG &lt;= 15.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>173</td>
#       <td>[0.9390243902439024] (RELMNG &lt;= 8.5) and (GU &lt;= 9.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2</td>
#       <td>55</td>
#       <td>[0.9482758620689655] (RELMNG &gt; 8.5) and (RELMNG &gt; 15.5) and (RELMNG &gt; 26.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>174</td>
#       <td>[0.64] (RELMNG &lt;= 8.5) and (GU &gt; 9.5) and (GU &lt;= 10.5)<br><br>[1.0] (RELMNG &lt;= 8.5) and (GU &gt; 9.5) and (GU &gt; 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>81</td>
#       <td>[0.8860759493670886] (RELMNG &gt; 8.5) and (RELMNG &gt; 15.5) and (RELMNG &lt;= 26.5) and (GU &lt;= 11.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>99</td>
#       <td>[1.0] (RELMNG &gt; 8.5) and (RELMNG &gt; 15.5) and (RELMNG &lt;= 26.5) and (GU &gt; 11.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'EL'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>85</td>
#       <td>[0.9518072289156626] (EL &gt; 7.5) and (EL &lt;= 22.5) and (EL &gt; 14.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>150</td>
#       <td>[0.869281045751634] (EL &lt;= 7.5) and (EL &lt;= 1.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>131</td>
#       <td>[0.927007299270073] (EL &gt; 7.5) and (EL &lt;= 22.5) and (EL &lt;= 14.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>97</td>
#       <td>[1.0] (EL &gt; 7.5) and (EL &gt; 22.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>143</td>
#       <td>[0.9310344827586207] (EL &lt;= 7.5) and (EL &gt; 1.5) and (GU &gt; 7.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>59</td>
#       <td>[0.76] (EL &lt;= 7.5) and (EL &gt; 1.5) and (GU &lt;= 7.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['REFMNG', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>155</td>
#       <td>[0.9393939393939394] (REFMNG &lt;= 5.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>140</td>
#       <td>[0.9574468085106383] (REFMNG &gt; 5.5) and (RELMNG &gt; 9.5) and (RELMNG &gt; 18.5) and (RELMNG &lt;= 26.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>104</td>
#       <td>[0.9158878504672897] (REFMNG &gt; 5.5) and (RELMNG &gt; 9.5) and (RELMNG &lt;= 18.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>82</td>
#       <td>[0.9186046511627907] (REFMNG &gt; 5.5) and (RELMNG &lt;= 9.5) and (REFMNG &gt; 11.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4</td>
#       <td>58</td>
#       <td>[1.0] (REFMNG &gt; 5.5) and (RELMNG &gt; 9.5) and (RELMNG &gt; 18.5) and (RELMNG &gt; 26.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>126</td>
#       <td>[0.9722222222222222] (REFMNG &gt; 5.5) and (RELMNG &lt;= 9.5) and (REFMNG &lt;= 11.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['REFMNG', 'EL'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>134</td>
#       <td>[1.0] (REFMNG &gt; 10.5) and (EL &lt;= 13.5) and (EL &gt; 6.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>107</td>
#       <td>[0.7619047619047619] (REFMNG &lt;= 10.5) and (REFMNG &gt; 4.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>100</td>
#       <td>[1.0] (REFMNG &gt; 10.5) and (EL &gt; 13.5) and (EL &gt; 21.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>142</td>
#       <td>[0.8865248226950354] (REFMNG &lt;= 10.5) and (REFMNG &lt;= 4.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4</td>
#       <td>90</td>
#       <td>[1.0] (REFMNG &gt; 10.5) and (EL &gt; 13.5) and (EL &lt;= 21.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>92</td>
#       <td>[1.0] (REFMNG &gt; 10.5) and (EL &lt;= 13.5) and (EL &lt;= 6.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['RELMNG', 'EL'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>123</td>
#       <td>[0.8467153284671532] (EL &gt; 4.5) and (RELMNG &lt;= 11.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>81</td>
#       <td>[0.9523809523809523] (EL &gt; 4.5) and (RELMNG &gt; 11.5) and (EL &gt; 21.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2</td>
#       <td>50</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>233</td>
#       <td>[1.0] (EL &lt;= 4.5) and (RELMNG &lt;= 5.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>85</td>
#       <td>[0.5081967213114754] (EL &lt;= 4.5) and (RELMNG &gt; 5.5)<br><br>[0.5353535353535354] (EL &gt; 4.5) and (RELMNG &gt; 11.5) and (EL &lt;= 21.5) and (RELMNG &lt;= 21.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>93</td>
#       <td>[0.9746835443037974] (EL &gt; 4.5) and (RELMNG &gt; 11.5) and (EL &lt;= 21.5) and (RELMNG &gt; 21.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Silhouette and Dunn for K-means

# %%
lc=list(df.columns)
lc2=lc.copy()
silhlist2=[]

for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        aa1=lc.index(n1)
        aa2=lc.index(n2)
        name2=str(n1 +' and '+n2)
        xatt2=df.iloc[:,lambda df: [aa1, aa2]]
        xattsm=dfsm.iloc[:,lambda dfsm: [aa1, aa2]]
        
        kmeanssm = KMeans(numk)
        kmeanssm.fit(xattsm)
        kmeans1 = KMeans(numk)
        kmeans1.fit(xatt2)
        
        scoresm = metrics.silhouette_score(xatt2, kmeans1.labels_, metric='euclidean')
        scoresm=round(scoresm,4)
        scoresmsm = metrics.silhouette_score(xattsm, kmeanssm.labels_, metric='euclidean')
        scoresmsm=round(scoresmsm,4)
        silhitem=[name2,scoresm,scoresmsm]
        silhlist2.append(silhitem)

silhdf2 = pd.DataFrame(silhlist2, columns =['Attributes','Silhouetter Score','Sampling Silhouetter Score'])
silhdf2.sort_values(by='Silhouetter Score',ascending=False)
# Out:
#           Attributes  Silhouetter Score  Sampling Silhouetter Score
# 7  REFMNG and RELMNG             0.4783                      0.4806
# 2      SR and RELMNG             0.4683                      0.4606
# 9      RELMNG and EL             0.4533                      0.4534
# 8      REFMNG and EL             0.4460                      0.4506
# 3          SR and EL             0.4442                      0.4600
# 5      GU and RELMNG             0.4415                      0.3885
# 6          GU and EL             0.4093                      0.4311
# 1      SR and REFMNG             0.4041                      0.4176
# 0          SR and GU             0.3925                      0.4235
# 4      GU and REFMNG             0.3809                      0.3865

# %% [markdown]
# # Dunn Index

# %%
from sklearn.metrics.pairwise import euclidean_distances

lc=list(df.columns)
lc2=lc.copy()
dunnlist=[]
diameter_method='farthest'
cdist_method='nearest'


for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        aa1=lc.index(n1)
        aa2=lc.index(n2)
        name2=str(n1 +' and '+n2)
        xatt2=df.iloc[:,lambda df: [aa1, aa2]]
        kmeans1 = KMeans(numk)
        k = kmeans1.fit_predict(xatt2)
        d = euclidean_distances(xatt2)
        dunk = 5*dunn(k, d, diameter_method, cdist_method)
        dunk=round(dunk,4)
        
        xattsm=dfsm.iloc[:,lambda dfsm: [aa1, aa2]]
        kmeanssm = KMeans(numk)
        ksm = kmeanssm.fit_predict(xattsm)
        dsm = euclidean_distances(xattsm)
        dunksm = 5*dunn(ksm, dsm, diameter_method, cdist_method)
        dunksm=round(dunksm,4)
        
        dunnitem=[name2,dunk,dunksm]
        dunnlist.append(dunnitem)

dunndf = pd.DataFrame(dunnlist, columns =['Attributes','DunnIndex','Sampling DunnIndex'])
dunndf.sort_values(by='DunnIndex',ascending=False).head(10)
# Out:
#           Attributes  DunnIndex  Sampling DunnIndex
# 4      GU and REFMNG     0.4138              0.4545
# 0          SR and GU     0.4042              0.4272
# 6          GU and EL     0.3953              0.3835
# 1      SR and REFMNG     0.3727              0.3727
# 2      SR and RELMNG     0.3590              0.2497
# 5      GU and RELMNG     0.3467              0.3492
# 3          SR and EL     0.3125              0.3125
# 7  REFMNG and RELMNG     0.3071              0.3363
# 8      REFMNG and EL     0.2509              0.2509
# 9      RELMNG and EL     0.2191              0.2428

# %% [markdown]
# # Davies-Bouldin Index

# %%
from sklearn.metrics import davies_bouldin_score

lc=list(df.columns)
lc2=lc.copy()
davieslist=[]
diameter_method='farthest'
cdist_method='nearest'


for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        aa1=lc.index(n1)
        aa2=lc.index(n2)
        name2=str(n1 +' and '+n2)
        xatt2=df.iloc[:,lambda df: [aa1, aa2]]
        kmeans1 = KMeans(numk)
        kmeans1.fit(xatt2)
        labels = kmeans1.labels_
        dab=davies_bouldin_score(xatt2, labels)
        
        
        xattsm=dfsm.iloc[:,lambda dfsm: [aa1, aa2]]
        kmeanssm = KMeans(numk)
        kmeanssm.fit(xattsm)
        labelsm = kmeanssm.labels_
        dabsm=davies_bouldin_score(xattsm, labelsm)
        
        
        daviesitem=[name2,dab,dabsm]
        davieslist.append(daviesitem)

daviesdf = pd.DataFrame(davieslist, columns =['Attributes','Davies','Sampling Davies'])
daviesdf.sort_values(by='Sampling Davies').head(10)
# Out:
#           Attributes    Davies  Sampling Davies
# 7  REFMNG and RELMNG  0.736090         0.761465
# 0          SR and GU  0.832751         0.771667
# 6          GU and EL  0.801702         0.774979
# 1      SR and REFMNG  0.913100         0.811064
# 8      REFMNG and EL  0.814236         0.822860
# 2      SR and RELMNG  0.772851         0.828004
# 4      GU and REFMNG  0.819891         0.830118
# 3          SR and EL  0.808904         0.835388
# 9      RELMNG and EL  0.829954         0.840740
# 5      GU and RELMNG  0.902962         0.897810

# %% [markdown]
# # Hierarchical

# %%
linked = linkage(dfsm, 'complete') 
dendrogram(linked, orientation='top', distance_sort='ascending', show_leaf_counts=False,color_threshold=25.0) 
plt.show()

# %%
modelac = AgglomerativeClustering(n_clusters=numk, linkage='complete')
modelac.fit(xatt)

aclabel = modelac.fit_predict(xatt)

scoresm = metrics.silhouette_score(xatt, modelac.labels_, metric='euclidean')

d = euclidean_distances(xatt)
diameter_method='farthest'
cdist_method='nearest'
dunk = dunn(aclabel, d, diameter_method, cdist_method)

print(scoresm,dunk)


fig, ax = plt.subplots() 
plt.scatter(df.iloc[:,a1], df.iloc[:,a2], c=modelac.labels_)
# Out:
# 0.3953137669112159 0.06401843996644799

# %% [markdown]
# # 300

# %%
#data=300

lc=list(df.columns)
lc2=lc.copy()

ahsilhlist=[]


for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        aa1=lc.index(n1)
        aa2=lc.index(n2)
        xatt2=df.iloc[:,lambda df: [aa1, aa2]]
        modelac2 = AgglomerativeClustering(n_clusters=numk, linkage='complete')
        modelac2.fit(xatt2)
        yac=modelac2.fit_predict(xatt2)

        cluster_report(xatt2, yac, min_samples_leaf=50, pruning_level=0.01)
        
        fig, ax = plt.subplots()
        scatter=plt.scatter(df.iloc[:,aa1], df.iloc[:,aa2], c=yac) 
        plt.title('Hierarchical Clustering with data=300: '+n1 + ' vs '+ n2)
        plt.xlabel(lc[lc.index(n1)])
        plt.ylabel(lc2[lc2.index(n2)])
        plt.colorbar(scatter)
        plt.show()
# Out:
# Index(['SR', 'GU'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>57</td>
#       <td>[0.7424242424242424] (SR &gt; 5.5) and (SR &gt; 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>67</td>
#       <td>[0.7560975609756098] (SR &gt; 5.5) and (SR &lt;= 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>47</td>
#       <td>[0.6811594202898551] (SR &lt;= 5.5) and (GU &lt;= 9.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3</td>
#       <td>10</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>16</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>5</td>
#       <td>103</td>
#       <td>[1.0] (SR &lt;= 5.5) and (GU &gt; 9.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'REFMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>66</td>
#       <td>[0.9682539682539683] (REFMNG &gt; 7.5) and (SR &lt;= 4.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>71</td>
#       <td>[0.7710843373493976] (REFMNG &gt; 7.5) and (SR &gt; 4.5) and (REFMNG &lt;= 15.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>75</td>
#       <td>[0.8571428571428571] (REFMNG &lt;= 7.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>17</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>60</td>
#       <td>[0.8142857142857143] (REFMNG &gt; 7.5) and (SR &gt; 4.5) and (REFMNG &gt; 15.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>11</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>63</td>
#       <td>[0.7160493827160493] (RELMNG &gt; 11.5) and (SR &gt; 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>146</td>
#       <td>[0.990990990990991] (RELMNG &lt;= 11.5) and (SR &lt;= 4.5)<br><br>[0.6428571428571429] (RELMNG &lt;= 11.5) and (SR &gt; 4.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>20</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3</td>
#       <td>10</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>41</td>
#       <td>[0.7115384615384616] (RELMNG &gt; 11.5) and (SR &lt;= 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>20</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'EL'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>59</td>
#       <td>[0.8405797101449275] (SR &gt; 3.5) and (EL &lt;= 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>49</td>
#       <td>[0.6333333333333333] (SR &gt; 3.5) and (EL &gt; 8.5) and (EL &lt;= 18.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>38</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3</td>
#       <td>12</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>4</td>
#       <td>110</td>
#       <td>[1.0] (SR &lt;= 3.5) and (EL &lt;= 1.5)<br><br>[0.7627118644067796] (SR &lt;= 3.5) and (EL &gt; 1.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>32</td>
#       <td>[0.6274509803921569] (SR &gt; 3.5) and (EL &gt; 8.5) and (EL &gt; 18.5)<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'REFMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>59</td>
#       <td>[0.8125] (REFMNG &lt;= 11.5) and (REFMNG &gt; 5.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>60</td>
#       <td>[0.7733333333333333] (REFMNG &lt;= 11.5) and (REFMNG &lt;= 5.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>78</td>
#       <td>[1.0] (REFMNG &gt; 11.5) and (GU &gt; 12.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>17</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>72</td>
#       <td>[0.7528089887640449] (REFMNG &gt; 11.5) and (GU &lt;= 12.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>14</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>39</td>
#       <td>[0.5] (RELMNG &gt; 5.5) and (RELMNG &gt; 15.5) and (RELMNG &lt;= 23.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>55</td>
#       <td>[0.7727272727272727] (RELMNG &gt; 5.5) and (RELMNG &lt;= 15.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>114</td>
#       <td>[0.68] (RELMNG &lt;= 5.5) and (GU &lt;= 8.5)<br><br>[0.9493670886075949] (RELMNG &lt;= 5.5) and (GU &gt; 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>44</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>28</td>
#       <td>[0.5283018867924528] (RELMNG &gt; 5.5) and (RELMNG &gt; 15.5) and (RELMNG &gt; 23.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>20</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'EL'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>36</td>
#       <td>[0.41509433962264153] (GU &lt;= 9.5) and (EL &gt; 1.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>100</td>
#       <td>[0.9215686274509803] (GU &gt; 9.5) and (EL &lt;= 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>36</td>
#       <td>[0.3684210526315789] (GU &gt; 9.5) and (EL &gt; 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>34</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>71</td>
#       <td>[0.98] (GU &lt;= 9.5) and (EL &lt;= 1.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>23</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['REFMNG', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>70</td>
#       <td>[0.9305555555555556] (REFMNG &gt; 8.5) and (RELMNG &lt;= 10.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>36</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>57</td>
#       <td>[0.95] (REFMNG &gt; 8.5) and (RELMNG &gt; 10.5) and (RELMNG &gt; 22.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>95</td>
#       <td>[0.9473684210526315] (REFMNG &lt;= 8.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>41</td>
#       <td>[0.5616438356164384] (REFMNG &gt; 8.5) and (RELMNG &gt; 10.5) and (RELMNG &lt;= 22.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>1</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['REFMNG', 'EL'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>77</td>
#       <td>[0.9382716049382716] (REFMNG &lt;= 6.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>53</td>
#       <td>[0.5463917525773195] (REFMNG &gt; 6.5) and (EL &gt; 11.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>57</td>
#       <td>[0.9] (REFMNG &gt; 6.5) and (EL &lt;= 11.5) and (EL &gt; 6.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3</td>
#       <td>2</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>66</td>
#       <td>[0.875] (REFMNG &gt; 6.5) and (EL &lt;= 11.5) and (EL &lt;= 6.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>45</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['RELMNG', 'EL'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>175</td>
#       <td>[0.9337016574585635] (RELMNG &lt;= 13.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>35</td>
#       <td>[0.6730769230769231] (RELMNG &gt; 13.5) and (EL &gt; 17.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>38</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>28</td>
#       <td>[0.417910447761194] (RELMNG &gt; 13.5) and (EL &lt;= 17.5)<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>17</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>7</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 600

# %%
#--------------------------------------data=600---------------------------------------------

lcsm=list(dfsm.columns)
lc2sm=lcsm.copy()

ahsilhsmlist=[]

for n1 in lcsm:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2sm.remove(n1)
    for n2 in lc2sm:
        aa1=lcsm.index(n1)
        aa2=lcsm.index(n2)
        xattsm=dfsm.iloc[:,lambda dfsm: [aa1, aa2]]
        modelacsm = AgglomerativeClustering(n_clusters=numk, linkage='complete')
        modelacsm.fit(xattsm)
        identified_clusters = modelacsm.fit_predict(xattsm)
        
        cluster_report(xattsm, identified_clusters, min_samples_leaf=50, pruning_level=0.01)
        
        fig, ax = plt.subplots()
        scatter=ax.scatter(dfsm.iloc[:,aa1], dfsm.iloc[:,aa2], c=modelacsm.labels_)
        plt.title('Hierarchical Clustering with data=665: '+n1 + ' vs '+ n2)
        plt.xlabel(lcsm[lcsm.index(n1)])
        plt.ylabel(lc2sm[lc2sm.index(n2)])
        plt.colorbar(scatter)
        plt.show()
# Out:
# Index(['SR', 'GU'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>226</td>
#       <td>[0.9319371727748691] SR &gt; 4.5 and GU &lt;= 13.5 and GU &gt; 8.5<br><br>[0.4] SR &gt; 4.5 and GU &gt; 13.5 and GU &lt;= 15.5<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>108</td>
#       <td>[1.0] SR &lt;= 4.5 and GU &lt;= 7.5<br><br>[0.4838709677419355] SR &gt; 4.5 and GU &lt;= 13.5 and GU &lt;= 8.5<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>235</td>
#       <td>[0.960352422907489] SR &lt;= 4.5 and GU &gt; 7.5<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>25</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4</td>
#       <td>15</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5</td>
#       <td>56</td>
#       <td>[0.7843137254901961] SR &gt; 4.5 and GU &gt; 13.5 and GU &gt; 15.5<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'REFMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>154</td>
#       <td>[1.0] REFMNG &lt;= 4.5<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>139</td>
#       <td>[0.8492063492063492] REFMNG &gt; 4.5 and REFMNG &lt;= 15.5 and REFMNG &lt;= 10.5<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>116</td>
#       <td>[0.8210526315789474] REFMNG &gt; 4.5 and REFMNG &lt;= 15.5 and REFMNG &gt; 10.5 and SR &gt; 4.5 and REFMNG &lt;= 13.5<br><br>[0.4642857142857143] REFMNG &gt; 4.5 and REFMNG &lt;= 15.5 and REFMNG &gt; 10.5 and SR &gt; 4.5 and REFMNG &gt; 13.5<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3</td>
#       <td>34</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>81</td>
#       <td>[0.5333333333333333] REFMNG &gt; 4.5 and REFMNG &lt;= 15.5 and REFMNG &gt; 10.5 and SR &lt;= 4.5<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>141</td>
#       <td>[0.625] REFMNG &gt; 4.5 and REFMNG &gt; 15.5 and SR &lt;= 10.5<br><br>[0.87] REFMNG &gt; 4.5 and REFMNG &gt; 15.5 and SR &gt; 10.5<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>152</td>
#       <td>[0.9047619047619048] RELMNG &gt; 8.5 and RELMNG &lt;= 22.5 and RELMNG &gt; 14.5<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>104</td>
#       <td>[0.5428571428571428] RELMNG &gt; 8.5 and RELMNG &gt; 22.5 and SR &lt;= 11.5<br><br>[1.0] RELMNG &gt; 8.5 and RELMNG &gt; 22.5 and SR &gt; 11.5<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>100</td>
#       <td>[1.0] RELMNG &lt;= 8.5 and SR &gt; 5.5<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3</td>
#       <td>5</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>53</td>
#       <td>[0.71875] RELMNG &gt; 8.5 and RELMNG &lt;= 22.5 and RELMNG &lt;= 14.5<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>5</td>
#       <td>251</td>
#       <td>[0.9400749063670412] RELMNG &lt;= 8.5 and SR &lt;= 5.5<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['SR', 'EL'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>162</td>
#       <td>[0.9864864864864865] EL &gt; 6.5 and EL &lt;= 17.5 and SR &lt;= 11.5<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>108</td>
#       <td>[1.0] EL &gt; 6.5 and EL &gt; 17.5 and SR &lt;= 11.5<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>310</td>
#       <td>[0.9506172839506173] EL &lt;= 6.5<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3</td>
#       <td>20</td>
#       <td>[0.4] EL &gt; 6.5 and EL &gt; 17.5 and SR &gt; 11.5<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>35</td>
#       <td>[0.4117647058823529] EL &gt; 6.5 and EL &lt;= 17.5 and SR &gt; 11.5<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>30</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'REFMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>65</td>
#       <td>[0.782051282051282] REFMNG &lt;= 13.5 and REFMNG &lt;= 6.5 and GU &lt;= 8.5<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>194</td>
#       <td>[0.8853503184713376] REFMNG &lt;= 13.5 and REFMNG &gt; 6.5 and GU &lt;= 12.5<br><br>[0.5] REFMNG &lt;= 13.5 and REFMNG &gt; 6.5 and GU &gt; 12.5<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2</td>
#       <td>41</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>124</td>
#       <td>[0.9298245614035088] REFMNG &gt; 13.5 and GU &gt; 14.5<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>96</td>
#       <td>[0.96] REFMNG &lt;= 13.5 and REFMNG &lt;= 6.5 and GU &gt; 8.5<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>145</td>
#       <td>[0.3904761904761905] REFMNG &gt; 13.5 and GU &lt;= 14.5 and REFMNG &lt;= 16.5<br><br>[0.96] REFMNG &gt; 13.5 and GU &lt;= 14.5 and REFMNG &gt; 16.5<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>98</td>
#       <td>[0.8672566371681416] RELMNG &gt; 3.5 and RELMNG &gt; 15.5 and RELMNG &gt; 23.5<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>158</td>
#       <td>[0.421875] RELMNG &gt; 3.5 and RELMNG &lt;= 15.5 and GU &lt;= 9.5<br><br>[0.9424460431654677] RELMNG &gt; 3.5 and RELMNG &lt;= 15.5 and GU &gt; 9.5<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>76</td>
#       <td>[1.0] RELMNG &gt; 3.5 and RELMNG &gt; 15.5 and RELMNG &lt;= 23.5 and GU &lt;= 12.0<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3</td>
#       <td>153</td>
#       <td>[1.0] RELMNG &lt;= 3.5 and GU &lt;= 9.5<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4</td>
#       <td>70</td>
#       <td>[1.0] RELMNG &gt; 3.5 and RELMNG &gt; 15.5 and RELMNG &lt;= 23.5 and GU &gt; 12.0<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>110</td>
#       <td>[1.0] RELMNG &lt;= 3.5 and GU &gt; 9.5<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['GU', 'EL'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>104</td>
#       <td>[0.9904761904761905] EL &gt; 4.5 and EL &gt; 20.5<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>70</td>
#       <td>[1.0] EL &lt;= 4.5 and GU &lt;= 6.5<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>83</td>
#       <td>[0.8247422680412371] EL &gt; 4.5 and EL &lt;= 20.5 and EL &gt; 12.5<br><br></td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>214</td>
#       <td>[1.0] EL &lt;= 4.5 and GU &gt; 6.5<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4</td>
#       <td>68</td>
#       <td>[0.625] EL &gt; 4.5 and EL &lt;= 20.5 and EL &lt;= 12.5 and GU &lt;= 9.5<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>126</td>
#       <td>[0.936] EL &gt; 4.5 and EL &lt;= 20.5 and EL &lt;= 12.5 and GU &gt; 9.5<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['REFMNG', 'RELMNG'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>158</td>
#       <td>[0.893491124260355] REFMNG &gt; 4.5 and RELMNG &gt; 8.5 and RELMNG &lt;= 21.5<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>152</td>
#       <td>[1.0] REFMNG &lt;= 4.5<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>76</td>
#       <td>[1.0] REFMNG &gt; 4.5 and RELMNG &lt;= 8.5 and REFMNG &gt; 12.5<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>92</td>
#       <td>[0.9213483146067416] REFMNG &gt; 4.5 and RELMNG &gt; 8.5 and RELMNG &gt; 21.5 and RELMNG &lt;= 26.5<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>4</td>
#       <td>58</td>
#       <td>[1.0] REFMNG &gt; 4.5 and RELMNG &gt; 8.5 and RELMNG &gt; 21.5 and RELMNG &gt; 26.5<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>129</td>
#       <td>[0.8601398601398601] REFMNG &gt; 4.5 and RELMNG &lt;= 8.5 and REFMNG &lt;= 12.5<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['REFMNG', 'EL'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>226</td>
#       <td>[0.9644444444444444] REFMNG &lt;= 8.5<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>98</td>
#       <td>[0.9238095238095239] REFMNG &gt; 8.5 and EL &gt; 14.5 and EL &lt;= 24.5<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>208</td>
#       <td>[0.9365853658536586] REFMNG &gt; 8.5 and EL &lt;= 14.5 and EL &gt; 3.5<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3</td>
#       <td>5</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>70</td>
#       <td>[1.0] REFMNG &gt; 8.5 and EL &gt; 14.5 and EL &gt; 24.5<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>58</td>
#       <td>[0.7666666666666667] REFMNG &gt; 8.5 and EL &lt;= 14.5 and EL &lt;= 3.5<br><br></td>
#     </tr>
#   </tbody>
# </table>
# Index(['RELMNG', 'EL'], dtype='object')
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>class_name</th>
#       <th>instance_count</th>
#       <th>rule_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>373</td>
#       <td>[1.0] RELMNG &lt;= 11.5 and EL &lt;= 8.5<br><br>[0.7192982456140351] RELMNG &lt;= 11.5 and EL &gt; 8.5<br><br></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>80</td>
#       <td>[0.9523809523809523] RELMNG &gt; 11.5 and EL &gt; 21.5<br><br></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>38</td>
#       <td>[0.6153846153846154] RELMNG &gt; 11.5 and EL &lt;= 21.5 and RELMNG &lt;= 20.5 and EL &lt;= 9.5<br><br></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>73</td>
#       <td>[0.9571428571428572] RELMNG &gt; 11.5 and EL &lt;= 21.5 and RELMNG &lt;= 20.5 and EL &gt; 9.5<br><br></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>81</td>
#       <td>[0.9310344827586207] RELMNG &gt; 11.5 and EL &lt;= 21.5 and RELMNG &gt; 20.5<br><br></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>20</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Silhouette and Dunn AC

# %%
#Silhouette

lc=list(df.columns)
lc2=lc.copy()
ahsilhlist=[]

for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        aa1=lc.index(n1)
        aa2=lc.index(n2)
        name2=str(n1 +' and '+n2)
        xatt2=df.iloc[:,lambda df: [aa1, aa2]]
        modelac2 = AgglomerativeClustering(n_clusters=numk, linkage='complete')
        modelac2.fit(xatt2)
        ahscoresm = metrics.silhouette_score(xatt2, modelac2.labels_, metric='euclidean')
        ahscoresm=round(ahscoresm,4)
        
        xattsm=dfsm.iloc[:,lambda dfsm: [aa1, aa2]]
        modelacsm = AgglomerativeClustering(n_clusters=numk, linkage='complete')
        modelacsm.fit(xattsm)
        ahscoresmsm = metrics.silhouette_score(xattsm, modelacsm.labels_, metric='euclidean')
        ahscoresmsm=round(ahscoresmsm,4)
        
        ahsilhitem=[name2,ahscoresm,ahscoresmsm]
        ahsilhlist.append(ahsilhitem)

ahsilhdf2 = pd.DataFrame(ahsilhlist, columns =['Attributes','Silhouetter Score','Sampling Silhouetter Score'])
ahsilhdf2.sort_values(by='Sampling Silhouetter Score',ascending=False,ignore_index=True)
# Out:
#           Attributes  Silhouetter Score  Sampling Silhouetter Score
# 0      RELMNG and EL             0.5093                      0.4904
# 1  REFMNG and RELMNG             0.4239                      0.4214
# 2      SR and REFMNG             0.4058                      0.4166
# 3      REFMNG and EL             0.4170                      0.4128
# 4          SR and EL             0.3960                      0.4033
# 5          GU and EL             0.3284                      0.3989
# 6      SR and RELMNG             0.4454                      0.3800
# 7      GU and REFMNG             0.3273                      0.3003
# 8      GU and RELMNG             0.3953                      0.2977
# 9          SR and GU             0.3084                      0.2913

# %%
#dunnindex Hierarchical


from sklearn.metrics.pairwise import euclidean_distances

lc=list(df.columns)
lc2=lc.copy()
acdunnlist=[]
diameter_method='farthest'
cdist_method='nearest'

for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        aa1=lc.index(n1)
        aa2=lc.index(n2)
        name2=str(n1 +' and '+n2)
        xatt2=df.iloc[:,lambda df: [aa1, aa2]]
        modelac2 = AgglomerativeClustering(n_clusters=numk, linkage='complete')
        k = modelac2.fit_predict(xatt2)
        d = euclidean_distances(xatt2)
        acdunk = 5*dunn(k, d, diameter_method, cdist_method)
        acdunk=round(acdunk,4)
        
        
        xatt2sm=dfsm.iloc[:,lambda df: [aa1, aa2]]
        modelac2sm = AgglomerativeClustering(n_clusters=numk, linkage='complete')
        ksm = modelac2sm.fit_predict(xatt2sm)
        dsm = euclidean_distances(xatt2sm)
        acsmdunk = 5*dunn(ksm, dsm, diameter_method, cdist_method)
        acsmdunk=round(acsmdunk,4)
        
        acdunnitem=[name2,acdunk,acsmdunk]
        acdunnlist.append(acdunnitem)

acdunndf = pd.DataFrame(acdunnlist, columns =['Attributes','DunnIndex','Sampling DunnIndex'])
acdunndf.sort_values(by='Sampling DunnIndex',ascending=False).head(10)
# Out:
#           Attributes  DunnIndex  Sampling DunnIndex
# 0          SR and GU     0.4623              0.4856
# 4      GU and REFMNG     0.4789              0.4704
# 6          GU and EL     0.4042              0.4138
# 1      SR and REFMNG     0.4110              0.4042
# 9      RELMNG and EL     0.2858              0.4042
# 7  REFMNG and RELMNG     0.3953              0.3590
# 3          SR and EL     0.3599              0.3333
# 5      GU and RELMNG     0.3201              0.3333
# 2      SR and RELMNG     0.3434              0.3162
# 8      REFMNG and EL     0.3283              0.3004

# %%
from sklearn.metrics import davies_bouldin_score

lc=list(df.columns)
lc2=lc.copy()
davieslist=[]
diameter_method='farthest'
cdist_method='nearest'


for n1 in lc:
    #print('Correlation for '+n1)
    #print(lc.index(n1))
    lc2.remove(n1)
    for n2 in lc2:
        aa1=lc.index(n1)
        aa2=lc.index(n2)
        name2=str(n1 +' and '+n2)
        xatt2=df.iloc[:,lambda df: [aa1, aa2]]
        modelac2 = AgglomerativeClustering(n_clusters=numk, linkage='complete')
        modelac2.fit(xatt2)
        labels = modelac2.labels_
        dab=davies_bouldin_score(xatt2, labels)
        
        
        xattsm=dfsm.iloc[:,lambda dfsm: [aa1, aa2]]
        modelacsm = AgglomerativeClustering(n_clusters=numk, linkage='complete')
        modelacsm.fit(xattsm)
        labelsm = modelacsm.labels_
        dabsm=davies_bouldin_score(xattsm, labelsm)
        
        
        daviesitem=[name2,dab,dabsm]
        davieslist.append(daviesitem)

daviesdf = pd.DataFrame(davieslist, columns =['Attributes','Davies','Sampling Davies'])
daviesdf.sort_values(by='Sampling Davies').head(10)
# Out:
#           Attributes    Davies  Sampling Davies
# 8      REFMNG and EL  0.872717         0.686498
# 9      RELMNG and EL  0.694734         0.757800
# 1      SR and REFMNG  0.834581         0.814735
# 3          SR and EL  0.970226         0.851588
# 7  REFMNG and RELMNG  0.739077         0.854914
# 2      SR and RELMNG  0.727959         0.856192
# 0          SR and GU  0.877005         0.890742
# 5      GU and RELMNG  0.859406         0.896229
# 6          GU and EL  0.874042         0.926774
# 4      GU and REFMNG  0.948109         0.938469

# %% [markdown]
# # Random Forest

# %%
a1=2
a2=3
xsm=dfsm.iloc[:,lambda df: [a1,a2]]
print(xsm)
# Out:
#      REFMNG  RELMNG
# 68       12      10
# 8         1       3
# 260      18      30
# 267      18      20
# 121      12       7
# ..      ...     ...
# 239      14      18
# 234      11       1
# 67        2       1
# 152      14       0
# 243       9      23
#
# [665 rows x 2 columns]

# %%
krf= KMeans(numk)
krf.fit(xsm)
ykm= krf.labels_

acrf = AgglomerativeClustering(n_clusters=numk, linkage='complete')
acrf.fit(xsm)
yac=acrf.labels_

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample
from sklearn.model_selection import train_test_split


xkm_train,xkm_test,ykm_train,ykm_test= train_test_split(xsm,ykm,test_size=0.3,random_state=0)
xac_train,xac_test,yac_train,yac_test= train_test_split(xsm,yac,test_size=0.3,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier

#max_depth=6,,min_samples_leaf=2,n_estimators=100
crfm=RandomForestClassifier(max_depth=17)

#Train the model using the training sets y_pred=clf.predict(X_test)
crfm.fit(xkm_train,ykm_train)

ykm_pred=crfm.predict(xkm_test)

cmrfm=confusion_matrix(ykm_test, ykm_pred)

# Transform to dataframe for easier plotting
cmrfm_df=pd.DataFrame(cmrfm) 

plt.figure(figsize=(8,5))
sns.heatmap(cmrfm_df, annot=True,linewidths=1, fmt = 'd')

plt.title("Random Forest Accuracy:"+str(crfm.score(xkm_test,ykm_test)*100))
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 24.0, 'Predicted label')

# %%
from sklearn.ensemble import RandomForestClassifier

#max_depth=6,,min_samples_leaf=2,n_estimators=100
crfa=RandomForestClassifier(max_depth=17)

#Train the model using the training sets y_pred=clf.predict(X_test)
crfa.fit(xac_train,yac_train)

yac_pred=crfa.predict(xac_test)

cmrfa=confusion_matrix(yac_test, yac_pred)

# Transform to dataframe for easier plotting
cmrfa_df=pd.DataFrame(cmrfa) 

plt.figure(figsize=(8,5))
sns.heatmap(cmrfa_df, annot=True,linewidths=1, fmt = 'd')

plt.title("Random Forest Accuracy:"+str(crfa.score(xac_test,yac_test)*100))
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 24.0, 'Predicted label')
